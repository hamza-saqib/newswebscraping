# %%
try:
    developmentMode = True
    callAPI = True
    Local_API_Laravel = 'http://127.0.0.1:8000/api/news/store'
    Live_API_Laravel = 'https://pakteki.com/api/news/store'
    Live_API_Node = 'http://3.142.50.232:5000/api/news/all'
    API = Live_API_Laravel
    Dawn = True
    Geo = True
    Ary = True
    Ptv = True
    Express = True
    Sama = True
    Duniya = True
    Bol = True
    Abbtak = True
    Ninetytwonews = True
    Abbtak = True
    Twentyfournews = False
    Gnnnews = True
    Dailypakistan = False
    Newsone = True
    Mashion = True
    Mangobaaz = True
    Sunday = True
    Urdunews = True
    Urdupoint = True
    Tribune = True
    Hellopakistanmag = True
    Zaiqa = False
    Islamicinfoenglish = False
    Islamicinfourdu = False
    Royal = True
    Neonews = False
    City42 = False
    Jang = True

    # libraries
    from bs4 import BeautifulSoup,Comment
    import requests
    import csv
    from datetime import date
    import pandas as pd
    import time

    # Array stucture for storing data
    columns = ['title','category', 'channel', 'permalink', 'image_src', 'date_time', 'description', 'fetching_date', 'language']
    rows, cols = (0, 9)
    data = [[0]*cols]*rows
except:
    print('exception in importing libraries ..')

# %%
try:
    sources = [
                ["https://www.dawn.com/trends/coronavirus", "Covid", "Dawn"],
               ["https://www.dawn.com/sport", "Sports", "Dawn"], 
               ["https://www.dawn.com/world", "International", "Dawn"],
               ["https://images.dawn.com/art-culture", "LifeStyle-Culture", "Dawn"],
               ["https://www.dawn.com/tech", "IT-Science", "Dawn"]
               ]
    if Dawn:
        counter = 0
        print('Getting Dawn News...')
        i = 1
        permalinkDawnNews = []
        for source in sources:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for article in soup.find_all('article', class_='box'):
                if i <= 6:
                    try:
                        permalink = article.find('a', class_='story__link')['href']
                        permalinkDawnNews.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkDawnNews
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')

            for div in soup.find_all('div',class_='w-full max-w-screen-md xl:pr-4'):
                try:
                    detail_title = div.find('div',class_='template__header').h2.a.text
                except:
                    detail_title = ''
                try:
                    high_resolution_image = div.find('div',class_='template__header').find('div',class_='slideshow').find('div',class_='slideshow__slide').figure.div.picture.img['src']
                except:
                    high_resolution_image = ''

                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_all = div.find('div',class_='template__main').find('div',class_='story__content').find_all('p')
                    detail_description = ''
                    for p in detail_description_all:
                        detail_description = detail_description + p.text
                except:
                    detail_description = ''
                counter = counter + 1

                language='English'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink':detail_page_source[0] ,
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                }
                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:20])
                    print('permalink:     ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter)) 
except:
    print('exception in ' + source[2])
# Out:
# Getting Dawn News...
# total news found on listting page : 30
#
# No:          1
# title:       Karachi's Covid-19 positivity rate tops 10pc as Omicron drives surge
# description: As the fifth wave of
# permalink:     https://www.dawn.com/news/1668143/karachis-covid-19-positivity-rate-tops-10pc-as-omicron-drives-surge
# channel:     Dawn
# image:       https://i.dawn.com/primary/2022/01/61d816eebb607.jpg
# category:    Covid
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          2
# title:       Election rallies cancelled as India sees Omicron surge
# description: NEW DELHI: Election
# permalink:     https://www.dawn.com/news/1668099/election-rallies-cancelled-as-india-sees-omicron-surge
# channel:     Dawn
# image:       https://i.dawn.com/primary/2022/01/61d7c3825fc61.jpg
# category:    Covid
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          3
# title:       Boris Johnson hits out at anti-vaxxers’ ‘mumbo jumbo’
# description: LONDON: British Prim
# permalink:     https://www.dawn.com/news/1668097/boris-johnson-hits-out-at-anti-vaxxers-mumbo-jumbo
# channel:     Dawn
# image:       https://i.dawn.com/primary/2022/01/61d7c4a1517b2.jpg
# category:    Covid
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          4
# title:       84-year-old Indian takes 11 Covid jabs
# description: NEW DELHI: An 84-yea
# permalink:     https://www.dawn.com/news/1668096/84-year-old-indian-takes-11-covid-jabs
# channel:     Dawn
# image:
# category:    Covid
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          5
# title:       
# image:
# category:    IT-Science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          21
# title:       Apple becomes first company to hit $3 trillion market value, then slips
# description: Apple Inc on Monday
# permalink:     https://www.dawn.com/news/1667594/apple-becomes-first-company-to-hit-3-trillion-market-value-then-slips
# channel:     Dawn
# image:       https://i.dawn.com/primary/2022/01/61d3efc17edd4.jpg
# category:    IT-Science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          22
# title:       An unstoppable tech frenzy
# description:  If and when the his
# permalink:     https://www.dawn.com/news/1667395/the-startup-capital-frenzy-is-not-stopping-any-time-soon
# channel:     Dawn
# image:
# category:    IT-Science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          23
# title:       Palestinians raise alarm over Facebook content 'suppression'
# description: Palestinian journali
# permalink:     https://www.dawn.com/news/1666820/palestinians-raise-alarm-over-facebook-content-suppression
# channel:     Dawn
# image:       https://i.dawn.com/primary/2021/12/61cead1de2806.jpg
# category:    IT-Science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
# total news scraped page : 23

# %%
try:
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
    sources2 = [
                ["https://arynews.tv/category/international-2", "International", "ARY"],
                ["https://arynews.tv/category/sci-techno/", "IT-Science", "ARY"], 
                ["https://arynews.tv/category/health-2/", "Health", "ARY"],
                ["https://arynews.tv/category/business/","Business","ARY"],
                ["https://arynews.tv/category/pakistan/","National-local","ARY"],
               ]
    if Ary == True:
        print('Getting ARY News...')
        i = 1
        counter = 0
        permalinkArrayARY = []
        for source in sources2:
            sourceHTML = requests.get(source[0],headers=headers).text
            soup = BeautifulSoup(sourceHTML,'lxml')
            for div in soup.find_all('div', class_='td-module-container'):
                if i <= 6:
                    try:
                        permalink = div.find('div',class_='td-module-meta-info').h3.a['href']
                        permalinkArrayARY.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArrayARY
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0],headers=headers).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div', class_='tdi_74'):
                try:
                    detail_title = div.find('div',class_='tdb_title').div.h2.text
                except:
                    detail_title = ''

                try:  
                    start = div.find('div',class_='tdb_single_bg_featured_image').style.find_next_sibling().text.find('url')
                    end = div.find('div',class_='tdb_single_bg_featured_image').style.find_next_sibling().text.find(')')
                    high_resolution_img_data = div.find('div',class_='tdb_single_bg_featured_image').style.find_next_sibling().text
                    high_resolution_image = high_resolution_img_data[start:end][5:-1]
                except:
                    high_resolution_image = ''
                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_all = div.div.div.find('div',class_='td_block_wrap tdb_single_content tdi_78 td-pb-border-top td_block_template_1 td-post-content test tagdiv-type').div.find_all('p')
                    detail_description = ''
                    for p in detail_description_all:
                        detail_description = detail_description + p.text
                except:
                    detail_description = ''
                counter = counter + 1
                language='English'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                            }
                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:80])
                    print('permalink:   ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])
# Out:
# Getting ARY News...
# total news found on listting page : 30
#
# No:          1
# title:       Dubai Economic Zones Authority announces new leadership team
# description: Sheikh Ahmed bin Saeed Al Maktoum, Chairman of Dubai Integrated Economic Zones A
# permalink:   https://arynews.tv/diez-announces-new-leadership-team/
# channel:     ARY
# image:       https://arynews.tv/wp-content/uploads/2022/01/DIEZ.jpg
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          2
# title:       India’s COVID-19 cases set for new highs as Omicron spreads
# description: NEW DELHI: India’s daily COVID-19 cases jumped to 117,100 on Friday, a five-fold
# permalink:   https://arynews.tv/india-covid-19-cases-omicron-variant-spread/
# channel:     ARY
# image:       https://arynews.tv/wp-content/uploads/2021/04/2-bed-India-coronavirus.jpg
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          3
# title:       CSTO peacekeeping troops reach Kazakhstan
# description: ALMATY: The Collective Security Treaty Organization (CSTO) has sent peacekeeping
# permalink:   https://arynews.tv/csto-peacekeeping-troops-reach-kazakhstan/
# channel:     ARY
# image:       https://arynews.tv/wp-content/uploads/2022/01/kazakhstan-peacekeeping-troops-csto.jpg
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          4
# title:       Biden assails Trump in speech marking anniversary of Capitol riot
# description: President Joe Biden tore into Donald Trump Thursday on the first anniversary of
# permalink:   https://arynews.tv/biden-assails-trump-anniversary-capitol-riot/
# channel:     ARY
# image:       https://arynews.tv/wp-content/uploads/2021/12/Biden.jpg
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          5
# title:       

# channel:     ARY
# image:       https://arynews.tv/wp-content/uploads/2022/01/DIEZ.jpg
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          20
# title:       #CES2022: Metaverse gets touch of reality
# description: A jacket equipped with sensors that let wearers feel hugs or even punches in vir
# permalink:   https://arynews.tv/ces-2022-metaverse-gets-touch-of-reality/
# channel:     ARY
# image:       https://arynews.tv/wp-content/uploads/2022/01/metaverse.jpg
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          21
# title:       Rupee recoups losses against US dollar
# description: KARACHI: The Pakistani rupee recouped some losses against the United States (US)
# permalink:   https://arynews.tv/rupee-recoups-losses-against-us-dollar/
# channel:     ARY
# image:       https://arynews.tv/wp-content/uploads/2021/11/US-dollar-pak-rupee.jpg
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          22
# title:       Silk Route Reconnect raises Pakistan’s exports to Central Asia: Dawood
# description: ISLAMABAD: Adviser to Prime Minister on Commerce Abdul Razak Dawood on Friday an
# permalink:   https://arynews.tv/silk-route-reconnect-raises-pakistans-exports-to-central-asia-dawood/
# channel:     ARY
# image:       https://arynews.tv/wp-content/uploads/2021/07/Afghanistan-Pakistan-Transit-Trade-Agreement-1.jpg
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          23
# title:       FBR collected Rs4,745 billion tax in 2020-21: Finance ministry
# description: ISLAMABAD: The Federal Board of Revenue (FBR) collected tax of Rs4,745 billion d
# permalink:   https://arynews.tv/fbr-collected-rs4745-billion-tax-in-2020-21-finance-ministry/
# channel:     ARY
# image:       https://arynews.tv/wp-content/uploads/2020/06/FBR-Pakistan-1-750x369-1.jpg
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          24
# title:       ‘Stock market claims highest profit of 10 years in 2021’
# description: ISLAMABAD: Finance Minister Shaukat Tarin on Friday shared that Pakistan’s stock
# permalink:   https://arynews.tv/stock-market-claims-highest-profit-of-10-years-in-2021/
# channel:     ARY
# image:       https://arynews.tv/wp-content/uploads/2020/09/Pakistan-Stock-Exchange.jpg
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          25
# title:       Police recover 20 hand grenades from Karachi’s Garden
# description: KARACHI: Police on Friday claimed to have foiled a terror bid and recovered 20 h
# permalink:   https://arynews.tv/police-recover-hand-grenades-from-karachi-garden/
# channel:     ARY
# image:       https://arynews.tv/wp-content/uploads/2022/01/grenade.jpg
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          26
# title:       Pakistan rejects India’s ‘false’ claims about SAARC, IIOJK
# description: ISLAMABAD: Pakistan on Friday categorically rejected India’s “false claims and t
# permalink:   https://arynews.tv/pakistan-rejects-indias-false-claims-about-saarc-iiojk/
# channel:     ARY
# image:       https://arynews.tv/wp-content/uploads/2021/10/foreign-office-1-1.jpg
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          27
# title:       Covid vaccination mandatory for students in Sindh
# description: KARACHI: With the fifth wave of the coronavirus intensifying in the country, the
# permalink:   https://arynews.tv/covid-vaccination-mandatory-for-students-in-sindh/
# channel:     ARY
# image:       https://arynews.tv/wp-content/uploads/2021/01/kpk-schools.jpg
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          28
# title:       Omicron: Has govt announced restrictions for Sindh?
# description: KARACHI: With the provincial authorities mulling over new restrictions to curb r
# permalink:   https://arynews.tv/omicron-has-govt-announced-restrictions-for-sindh/
# channel:     ARY
# image:       https://arynews.tv/wp-content/uploads/2022/01/270350630_1585291415167461_7151279060193476055_n.png
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          29
# title:       Four muggers arrested in two Islamabad police encounters in a day
# description: ISLAMABAD: Islamabad police on Friday claimed to have apprehended four muggers w
# permalink:   https://arynews.tv/muggers-islamabad-police-encounters-robbery/
# channel:     ARY
# image:       https://arynews.tv/wp-content/uploads/2017/09/Islamabad-police.jpg
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          30
# title:       136 more found infected with Omicron in Karachi
# description: KARACHI: As many as 136 more people were found infected with the Omicron variant
# permalink:   https://arynews.tv/136-more-found-infected-with-omicron-in-karachi/
# channel:     ARY
# image:       https://arynews.tv/wp-content/uploads/2021/12/omicron-covid-variant-vs-delta-1.jpg
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
# total news scraped page : 30

# %%
try:
    sources3 = [
                ["https://www.geo.tv/category/world", "International", "GEO"],
                ["https://www.geo.tv/category/sci-tech", "IT-Science", "GEO"], 
                ["https://www.geo.tv/category/sports", "Sports", "GEO"],
                ["https://www.geo.tv/category/entertainment", "Entertainment", "GEO"],
                ["https://www.geo.tv/category/business","Business","GEO"],
                ["https://www.geo.tv/food","Gourmet","GEO"],
               ]
    if Geo == True:
        print('Getting GEO News...')
        i = 1
        counter = 0
        permalinkArrayGeoNews = []
        for source in sources3:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div', class_='col-xs-6 col-sm-6 col-lg-6 col-md-6 singleBlock'):
                if i <= 6:
                    try:
                        permalink = div.div.ul.li.a['href']
                        permalinkArrayGeoNews.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArrayGeoNews
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='column-right'):
                try:
                    detail_title = div.find('div',class_='left').find('div',class_='story-area').h1.text
                except:
                    detail_title = ''
                try:
                    high_resolution_image = div.find('div',class_='story-area').find('div',class_='content-area').find('div',class_='medium-insert-images').figure.img['src']
                except:
                    high_resolution_image = ''
                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_all = div.find('div',class_='left').find('div',class_='story-area').find('div',class_='content-area').find_all('p')
                    detail_description = ''
                    for p in detail_description_all:
                        detail_description = detail_description + p.text
                except:
                    detail_description = ''
                counter = counter + 1
                language='English'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                            }
                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:80])
                    print('permalink:     ' + detail_page_source[0].strip())
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image.strip())
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])
# Out:
# Getting GEO News...
# total news found on listting page : 30
#
# No:          1
# title:       Dog custody: Spain to consider pets' welfare in divorce battles
# description: MADRID: Spain will consider a pet's welfare when couples divorce or break up fro
# permalink:     https://www.geo.tv/latest/392113-dog-custody-spain-to-consider-pets-welfare-in-divorce-battles
# channel:     GEO
# image:       https://www.geo.tv/assets/uploads/updates/2022-01-07/392113_1595108_updates.jpg
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          2
# title:       Kazakh president says constitutional order has mostly been restored
# description: ALMATY: Kazakh President Kassym-Jomart Tokayev said on Friday that constitutiona
# permalink:     https://www.geo.tv/latest/392058-kazakh-president-says-constitutional-order-has-mostly-been-restored
# channel:     GEO
# image:       https://www.geo.tv/assets/uploads/updates/2022-01-07/392058_8920117_updates.jpg
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          3
# title:       Omicron may be less severe in young and old, but not 'mild', WHO says
# description: The more infectious Omicron variant of COVID-19 appears to produce less severe d
# permalink:     https://www.geo.tv/latest/392038-omicron-may-be-less-severe-in-young-and-old-but-not-mild-who-says
# channel:     GEO
# image:       https://www.geo.tv/assets/uploads/updates/2022-01-07/392038_4801539_updates.jpg
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          4
# title:       Russia sends troops to put down Kazakhstan uprising as fresh violence erupts
# description: ALMATY: Fresh violence erupted in Kazakhstan's main city of Almaty on Thursday a
# permalink:     https://www.geo.tv/latest/392029-russia-sends-troops-to-put-down-kazakhstan-uprising-as-fresh-violence
# channel:     GEO
# image:       https://www.geo.tv/assets/uploads/updates/2022-01-07/392029_9894714_updates.jpg
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          5
# title:       From stability to turmoil — what's going on in Kazakhstan
# description: Soldiers shot at protesters in Kazakhstan's biggest city Almaty on Thursday afte
# permalink:     https://www.geo.tv/latest/391971-from-stability-to-turmoil-whats-going-on-in-kazakhstan
# channel:     GEO
# image:       https://www.geo.tv/assets/uploads/updates/2022-01-06/391971_9015243_updates.jpg
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          6
# title:       One year on, Trump backers recall 'incredible' Capitol siege
# description: One year ago to the day, they descended upon Washington in the thousands, gather
# permalink:     https://www.geo.tv/latest/391972-one-year-on-trump-backers-recall-incredible-capitol-siege
# channel:     GEO
# image:       https://www.geo.tv/assets/uploads/updates/2022-01-06/391972_9618359_updates.jpg
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          7
# title:       Apple becomes first company to hit $3 trillion market value, then slips
# description: Apple Inc on Monday became the first company to hit a $3 trillion stock market v
# permalink:     https://www.geo.tv/latest/391542-apple-becomes-first-company-to-hit-3-trillion-market-value-then-slips
# channel:     GEO
# image:       https://www.geo.tv/assets/uploads/updates/2022-01-04/391542_6393253_updates.jpg
# category:    IT-Science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          8
# title:       Apple becomes 1st US company to reach $3 tn valuation
# description: NEW YORK: Apple became the first US company to hit $3 trillion in market value,
# permalink:     https://www.geo.tv/latest/391433-apple-becomes-1st-us-company-to-reach-3-tn-valuation
# channel:     GEO
# image:       https://www.geo.tv/assets/uploads/updates/2022-01-04/391433_3065094_updates.jpg
# category:    IT-Science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          9
# title:       Denmark aims for all domestic flights to be green by 2030
# description: COPENHAGEN: Denmark's government has set an ambitious target of making all Danis
# permalink:     https://www.geo.tv/latest/391082-denmark-aims-for-all-domestic-flights-to-be-green-by-2030
# channel:     GEO
# image:       https://www.geo.tv/assets/uploads/updates/2022-01-02/391082_5572808_updates.jpg
# category:    IT-Science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          10
# title:       CES tech show shutting down a day early amid Covid surge
# description: LAS VEGAS: The CES tech show announced Friday that the Las Vegas event next week
# permalink:     https://www.geo.tv/latest/390904-ces-tech-show-shutting-down-a-day-early-amid-covid-surge
# channel:     GEO
# image:       https://www.geo.tv/assets/uploads/updates/2022-01
# channel:     GEO
# image:       https://www.geo.tv/assets/uploads/updates/2022-01-07/392112_3781947_updates.jpg
# category:    Entertainment
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          23
# title:       Tom Holland recalls pitching for James Bond origin film: ‘dream of a young kid’
# description: Tom Holland recently recalled his dream of starring in James Bond movie as he re
# permalink:     https://www.geo.tv/latest/392106-tom-holland-recalls-pitching-for-james-bond-origin-film-dream-of-a-young-kid
# channel:     GEO
# image:       https://www.geo.tv/assets/uploads/updates/2022-01-07/392106_5082875_updates.jpg
# category:    Entertainment
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          24
# title:       Andrew Garfield says he is ‘definitely open’ to return as ‘Spider-Man’
# description: Andrew Garfield has finally sounded off on his surprise appearance in the blockb
# permalink:     https://www.geo.tv/latest/392092-andrew-garfield-is-definitely-open-to-return-as-spider-man
# channel:     GEO
# image:       https://www.geo.tv/assets/uploads/updates/2022-01-07/392092_9755387_updates.jpg
# category:    Entertainment
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          25
# title:       Sales tax on goods falls under federal govt's jurisdiction: Tarin
# description: ISLAMABAD: Federal Minister for Finance and Revenue Shaukat Tarin on Thursday cl
# permalink:     https://www.geo.tv/latest/392119-sales-tax-on-goods-falls-under-federal-govts-jurisdiction-tarin
# channel:     GEO
# image:       https://www.geo.tv/assets/uploads/updates/2022-01-07/392119_2546683_updates.jpg
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          26
# title:       Rupee rebounds as SBP curbs certain outflows
# description: KARACHI: Pakistan currency recovered slightly against the US dollar on the last
# permalink:     https://www.geo.tv/latest/392095-rupee-rebounds-as-sbp-curbs-certain-outflows
# channel:     GEO
# image:       https://www.geo.tv/assets/uploads/updates/2022-01-07/392095_2941815_updates.jpg
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          27
# title:       Senate body rejects several finance bill proposals
# description: ISLAMABAD: The Federal Board of Revenue (FBR) on Thursday sought the right from
# permalink:     https://www.geo.tv/latest/391905-senate-body-rejects-several-finance-bill-proposals
# channel:     GEO
# image:       https://www.geo.tv/assets/uploads/updates/2022-01-06/391905_2645358_updates.jpg
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          28
# title:       Gold cuts losses as rupee slips against US dollar
# description: KARACHI: Gold prices in Pakistan were confined to a small range in seasonally-qu
# permalink:     https://www.geo.tv/latest/391931-gold-cuts-losses-as-rupee-slips-against-us-dollar
# channel:     GEO
# image:       https://www.geo.tv/assets/uploads/updates/2022-01-06/391931_4935979_updates.jpg
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          29
# title:       Rupee weakens by 0.10% against US dollar
# description: KARACHI: After a day's respite, the Pakistani rupee continued to lose its ground
# permalink:     https://www.geo.tv/latest/391897-rupee-weakens-by-010-against-us-dollar
# channel:     GEO
# image:       https://www.geo.tv/assets/uploads/updates/2022-01-06/391897_3985005_updates.jpg
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          30
# title:       'Mini-budget' an attempt to bring tsunami of inflation: Senate committee
# description:  ISLAMABAD: The Senate Standing Committee on Finance has termed the "mini-budget
# permalink:     https://www.geo.tv/latest/391814-mini-budget-an-attempt-to-bring-tsunami-of-inflation-senate-standing-committee
# channel:     GEO
# image:       https://www.geo.tv/assets/uploads/updates/2022-01-06/391814_8836195_updates.jpg
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
# total news scraped page : 30

# %%
try:
    sources4 = [
                ["https://ptv.com.pk/ptvWorld/news/National", "National-Local", "PTV"],
                ["https://ptv.com.pk/ptvWorld/news/Cricket", "Sports", "PTV"], 
                ["https://ptv.com.pk/ptvWorld/news/International", "International", "PTV"]
                ]
    if Ptv == True:
        print('Getting PTV News...')
        counter = 0
        i = 1
        permalinkArrayPTV = []
        for source in sources4:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for article in soup.find_all('ul', class_='big'):
                if i <= 6:
                    try:
                        permalink = article.li.div.div.h4.a['href']
                        permalinkArrayPTV.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArrayPTV
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='page'):
                try:
                    detail_title = div.find('div',class_='row').find('div',class_='column_2_3').find('div',class_='row').div.div.h3.text
                except:
                    detail_title = ''
                try:
                    high_resolution_image = div.find('div',class_='row').find('div',class_='column_2_3').find('div',class_='row').div.img['src']
                except:
                    high_resolution_image = ''
                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description = div.find('div',class_='row').find('div',class_='column_2_3').find('div',class_='row').div.div.div.p.text.replace('\n','')
                except:
                    detail_description = '.'
                counter = counter + 1
                language = 'English'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': permalink,
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                            }

                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:80])
                    print('permalink:   ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])
# Out:
# Get
jpg
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          18
# title:       U.S. Covid Concerns : Country Sets Global Record Of Over 1m Daily Cases
# description:  The United States recorded more than one million covid-19 cases, as the Omicron
# permalink:   https://ptv.com.pk/ptvWorld/engNewsDetail/37356
# channel:     PTV
# image:       https://ptv.com.pk/newsimages/Jan-04-2022-20.56.02_WORLD (47).jpg
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
# total news scraped page : 18

# %%
try:
    sources5 = [["https://www.express.pk/health/", "Health", "Express"],
                ["https://www.express.pk/sports/", "Sports", "Express"],
                ["https://www.express.pk/world/", "International", "Express"],
                ["https://www.express.pk/science/", "IT-Science", "Express"],
                ["https://www.express.pk/pakistan/", "National-Local", "Express"],
                ["https://www.express.pk/religion/", "Islam", "Express"]
               ]
    if Express == True:
        print('Getting Express News...')
        counter = 0
        i = 1
        permalinkArrayExpressNews = []
        for source in sources5:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='cstoreyitem'):
                if i <= 6:
                    try:
                        permalink = div.div.a['href']
                        permalinkArrayExpressNews.append([permalink,source[1],source[2]])
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArrayExpressNews
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='primary'):
                try:
                    detail_title = div.div.h1.text.replace('\xa0','')
                except:
                    detail_title = ''
                try:
                    high_resolution_image = div.div.find('div',class_='span-10').div.div.img['src']
                except:
                    high_resolution_image = ''
                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_all = div.div.find('div',class_='span-16 story-cont').find_all('p')
                    detail_description = ''
                    for p in detail_description_all:
                        detail_description = detail_description + p.text.replace('\n','').replace('\xa0','')
                except:
                    detail_description = ''
                counter = counter + 1
                language='Urdu'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': permalink,
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                            }
                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:80])
                    print('permalink:   ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])
# Out:
# Getting Express News...
# total news found on listting page : 0
#
# No:          1
# title:       پہلی مرتبہ دماغ میں اوسی ڈی کی وجہ بننے والا برقی عمل دریافت
# description: سائنسدانوں نے پہلی مرتبہ دماغی برقی سرگرمی معلوم کی ہے جو او سی ڈی کی وجہ بنتی ہ
# permalink:   https://www.express.pk/story/2267755/9812
# channel:     Express
# image:       https://c.express.pk/2022/01/2267755-brainmain-1641414569-254-640x480.jpg
# category:    Health
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          2
# title:       ڈیمنشیا روکنے والے اسپرے کی انسانی آزمائش جلد متوقع
# description: جاپانی سائنسدانوں نے ایک اینٹی بایوٹک دوا اور اینٹی آکسیڈنٹ پر مبنی ناک کا اسپر
# permalink:   https://www.express.pk/story/2267295/9812
# channel:     Express
# image:       https://c.express.pk/2022/01/2267295-nasal-1641320354-750-640x480.gif
# category:    Health
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          3
# title:       شکرقندی کولیسٹرول گھٹانے میں انتہائی مفید
# description: شکرقندی کولیسٹرول گھٹانے والی نہایت تیربہدف غذا ہے۔ فوٹو: فائل واشنگٹن:ایک بہت س
# permalink:   https://www.express.pk/story/2266964/9812
# channel:     Express
# image:       https://c.express.pk/2022/01/2266964-sweets-1641240167-408-640x480.gif
# category:    Health
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          4
# title:       فرانس میں کورونا وائرس کا نیا ویریئنٹ سامنے آگیا
# description: فرانس میں اب تک کورونا کی اس نئی شکل کے 12 کیسز سامنے آئے ہیں، فوٹو: فائل پیرس:
# permalink:   https://www.express.pk/story/2267566/9812
# channel:     Express
# image:       https://c.express.pk/2022/01/2267566-newcovidvarientdedectedinfrance-1641388996-131-640x480.jpg
# category:    Health
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          5
# title:       ملیٹھی ایک جادوئی شفائی جڑی بوٹی بھی ہے
# description: ملیٹھی کو سپرفوڈ کہا جاتا ہے جو کئی بیماریوں کا شافی علاج بھی ہے۔ فوٹو: فائل کرا
# permalink:   https://www.express.pk/story/2266928/9812
# channel:     Express
# image:       https://c.express.pk/2022/01/2266928-mulethi-1641232805-511-640x480.gif
# category:    Health
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          6
# title:       ویاگرا نے کووِڈ 19 سے شدید متاثرہ خاتون کی جان بچا لی
# description: وہ پہلی مریضہ ہیں جن پر کووِڈ 19 کے علاج کےلیے ویاگرا آزمائی گئی ہے۔ (فوٹو: انٹ
# permalink:   https://www.express.pk/story/2267068/9812
# channel:     Express
# image:       https://c.express.pk/2022/01/2267068-covidviagrax-1641281809-914-640x480.jpg
# category:    Health
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          7
# title:
640x480.jpg
# category:    Islam
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          35
# title:       کامیاب زندگی کی شاہ کلید
# description: مومن کی پہچان یہ ہے نعمتوں پر شکر بجا لاتا اور تکالیف و آزمائشوں پر صبر سے کام
# permalink:   https://www.express.pk/story/2262700/1
# channel:     Express
# image:       https://c.express.pk/2021/12/2262700-namazjumacoronavirusx-1640293357-764-640x480.jpg
# category:    Islam
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          36
# title:       اپنا محاسبہ کیجیے۔۔۔۔!
# description: سال مہینوں کی طرح اور مہینے دنوں کی طرح اور دن گھنٹوں کی طرح گزرتے چلے جارہے ہیں
# permalink:   https://www.express.pk/story/2259738/1
# channel:     Express
# image:       https://c.express.pk/2021/12/2259738-namazx-1639687541-484-640x480.jpg
# category:    Islam
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
# total news scraped page : 36

# %%
try:
    sources6 = [
                ["https://www.samaa.tv/lifeandstyle/", "National-Local", "SAMAA"],
                ["https://www.samaa.tv/sports/", "Sports", "SAMAA"], 
                ["https://www.samaa.tv/news/", "National-Local", "SAMAA"],
                ["https://www.samaa.tv/technology/", "IT-Science", "SAMAA"]
                ]
    if Sama == True:
        print('Getting SAMA News...')
        counter = 0
        i = 1
        permalinkArraySAMANews = []
        for source in sources6:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='categorycolumn'):
                if i <= 6:
                    try:
                        permalink = div.find('div',class_='row').find('div',class_='respnb1').a['href']
                        permalinkArraySAMANews.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArraySAMANews
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='col-md-8'):
                try:
                    detail_title = div.div.h1.text
                except:
                    detail_title = ''
                try:
                    high_resolution_image = ''
                    high_resolution_img_parent = div.find('div',class_='detail-10 detailnews').center
                    high_resolution_img_text = high_resolution_img_parent.find(text=lambda text:isinstance(text, Comment))
                    high_resolution_img_soup = BeautifulSoup(high_resolution_img_text , 'lxml')
                    high_resolution_image = high_resolution_img_soup.img['src']
                except:
                    high_resolution_img = ''
                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_all = div.find('div',class_='detailnews').find_all('p')
                    detail_description = ''
                    for p in detail_description_all:
                        detail_description = detail_description + p.text.replace('\n','').replace('\xa0','')
                except:
                    detail_description = ''
                counter = counter + 1   
                language='English'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                            }

                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:80])
                    print('permalink:   ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])
# Out:
# Getting SAMA News...
# total news found on listting page : 16
#
# No:          1
# title:       What not to miss at 16th Karachi International Book Fair
# description: Photo: SAMAA DigitalIf you want to see what a diverse Karachi has incommon, it i
# permalink:   https://www.samaa.tv/lifeandstyle/2022/01/what-not-to-miss-at-16th-karachi-international-book-fair/
# channel:     SAMAA
# image:       https://www.samaa.tv/wp-content/uploads/2022/01/Untitled-1-2.jpg
# category:    National-Local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          2
# title:       Naseeruddin Shah calls Mughals ‘refugees,’ warns of Indian ‘civil war’
# description:  Naseeruddin Shah is coming under fire for making comments on “civil war in Indi
# permalink:   https://www.samaa.tv/lifeandstyle/2021/12/naseeruddin-shah-calls-mughals-refugees-warns-of-indian-civil-war/
# channel:     SAMAA
# image:       https://www.samaa.tv/wp-content/uploads/2021/06/768042-749637-728395-naseeruddin-shah-090818.jpg
# category:    National-Local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          3
# title:       British socialite Ghislaine Maxwell convicted of sex trafficking
# description: Photo: AFP British socialite Ghislaine Maxwell was found guilty in New York on W
# permalink:   https://www.samaa.tv/lifeandstyle/2021/12/british-socialite-ghislaine-maxwell-convicted-of-sex-trafficking/
# channel:     SAMAA
# image:       https://www.samaa.tv/wp-content/uploads/2021/12/Ghislaine-Maxwell.png
# category:    National-Local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          4
# title:       In pictures: Christmas celebrations light up Pakistan
# description: Christian devotees pray in a church on Christmas Eve in Quetta on December 24, 2
# permalink:   https://www.samaa.tv/lifeandstyle/2021/12/in-pictures-christmas-preparations-in-full-swing-across-pakistan/
# channel:     SAMAA
# image:       https://www.samaa.tv/wp-content/uploads/2021/12/000_9V86DH.jpg
# category:    National-Local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          5
# title:       Pakistan team to get booster shots today: report
# description: Photo: AFPThe Pakistan CricketBoard (PCB) has reportedly decided to give a boost
# permalink:   https://www.samaa.tv/sports/cricket/2022/01/pakistan-team-to-get-booster-shots-today-report/
# channel:     SAMAA
# image:       https://www.samaa.tv/wp-content/uploads/2022/01/Pakistan-Team2.jpg
# category:    Sports
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          6
# title:       Hashim Amla in awe of ‘magician’ Mohammad Asif
# description: Photo: Screenshot-YouTube Former South Africabatter Hashim Amla has heaped prais
# permalink:   https://www.samaa.tv/sports/cricket/2022/01/hashim-amla-in-awe-of-magician-mohammad-asif/
# channel:     SAMAA
# image:       https://www.samaa.tv/wp-content/uploads/2022/01

# category:    IT-Science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
# total news scraped page : 16

# %%
try:
    sources7 = [
                ["https://dunyanews.tv/en/World", "International", "Dunya"],
                ["https://dunyanews.tv/en/Cricket", "Sports", "Dunya"], 
                ["https://dunyanews.tv/en/Pakistan", "National-Local", "Dunya"],
                ["https://dunyanews.tv/en/Technology", "IT-Science", "Dunya"],
                ["https://dunyanews.tv/en/Business","Business","Dunya"]
               ]
    if Duniya == True:
        counter = 0
        i = 1
        print('Getting Duniya News...')
        permalinkArrayDuniyaNews = []
        for source in sources7: 
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for article in soup.find_all('article'):
                if i <= 6:
                    if article.div.a['href']:
                        try:
                            permalink = 'https://dunyanews.tv' + article.div.a['href']
                            permalinkArrayDuniyaNews.append([permalink,source[1],source[2]])
                        except:
                            permalink = ''
                    else:
                        try:
                            permalink = 'https://dunyanews.tv' + article.h3.a['href']
                            permalinkArrayDuniyaNews.append([permalink,source[1],source[2]])
                        except:
                            permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArrayDuniyaNews
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')

            for div in soup.find_all('div',{'id':'main-heading'}):

                try:
                    detail_title = div.find('div',class_='date').h2.text
                except:
                    detail_title = ''
                try:
                    high_resolution_image = div.find('div',class_='date').find('div',{'id':'post_content'}).article.find('div',class_='pic').img['src']
                except:
                    high_resolution_image = ''
                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_all = div.find('div',class_='date').find('div',{'id':'post_content'}).article.find('div',class_='post_content').find_all('p')
                    detail_description = ''
                    for p in detail_description_all:
                        detail_description = detail_description + p.text.replace('\n','').replace('\xa0','')
                except:
                    detail_description = ''
                counter = counter + 1

                language='English'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': permalink,
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                            }

                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:80])
                    print('permalink:   ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])
# Out:
# Getting Duniya News...
# total news found on listting page : 0
#
# No:          1
# title:       Billionaire's looted art still on display at Israel Museum
# description: JERUSALEM (AP) — One of the Israel Museum’s biggest patrons, American billionair
# permalink:   https://dunyanews.tv/index.php/en/World/635891-Billionaire-looted-art-still-on-display-at-Israel-Museum
# channel:     Dunya
# image:       https://img.dunyanews.tv/news/2022/January/01-07-22/news_big_images/635891_99571632.jpg
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          2
# title:       As cases rise, India fears another Covid catastrophe
# description: NEW DELHI (AFP) - Haunted by the spectre of last year’s crisis, India is bracing
# permalink:   https://dunyanews.tv/index.php/en/World/635889-As-cases-rise-India-fears-another-Covid-catastrophe
# channel:     Dunya
# image:       https://img.dunyanews.tv/news/2022/January/01-07-22/news_big_images/635889_34531222.jpg
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          3
# title:       As cases rise, India fears another Covid catastrophe
# description: NEW DELHI (AFP) - Haunted by the spectre of last years crisis, India is bracing
# permalink:   https://dunyanews.tv/index.php/en/World/635888-As-cases-rise,-India-fears-another-Covid-catastrophe
# channel:     Dunya
# image:       https://img.dunyanews.tv/news/2022/January/01-07-22/news_big_images/635888_65024456.jpg
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          4
# title:       UK to deploy troops to virus-hit London hospitals
# description: LONDON (AFP) - Britain will deploy troops to hospitals in London to alleviate se
# permalink:   https://dunyanews.tv/index.php/en/World/635887-UK-to-deploy-troops-to-virus-hit-London-hospitals
# channel:     Dunya
# image:       https://img.dunyanews.tv/news/2022/January/01-07-22/news_big_images/635887_47606017.jpg
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          5
# title:       Clashes in largest Kazakh city, Moscow-led troops arrive
# description: ALMATY (AFP) - Bursts of gunfire echoed through the streets of Kazakhstans large
# permalink:   https://dunyanews.tv/index.php/en/World/635843-Clashes-in-largest-Kazakh-city,-Moscow-led-troops-arrive
# channel:     Dunya
# image:       https://img.dunyanews.tv/news/2022/January/01-07-22/news_big_images/635843_67816346.jpg
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          6
# title:       Tehran to Seoul: Don't wait to release frozen funds
# description: TEHRAN (AFP) - Iranian negotiator Ali Bagheri on Thursday urged South Korea to r
# permalink:   https://dunyanews.tv/index.php/en/World/635841-Tehran-to-Seoul:-Don\'t-wait-to-release-frozen-funds
# channel:     Dunya
# image:       https://img.dunyanews.tv/news/2022/January/01-07-22/news_big_images/635841_69713933.jpg
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          7
# title:       Babar's father praises son for winning "Cricketer of the Year" award
# description: LAHORE (Dunya News) – Pakistan Cricket team’s captain Babar Azam received praise
# permalink:   https://dunyanews.tv/index.php/en/Cricket/635892-Babars-father-praises-son-for-winning-Cricketer-of-the-Year-award
# channel:     Dunya
# image:       https://img.dunyanews.tv/news/2022/January/01-07-22/news_big_images/635892_52410094.jpg
# category:    Sports
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          8
# title:       Bairstow hits ton, Stokes defies pain as England fight back
# description: SYDNEY, (AFP) - Jonny Bairstow broke through for his first Test hundred in Austr
# permalink:   https://dunyanews.tv/index.php/en/Cricket/635877-Bairstow-hits-ton-Stokes-defies-pain-England-fight-back
# channel:     Dunya
# image:       https://img.dunyanews.tv/news/2022/January/01-07-22/news_big_images/635877_28865959.jpg
# category:    Sports
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          9
# title:       Dean Elgar takes the blows to inspire South African win over India
# description: JOHANNESBURG (AFP) - South African captain Dean Elgar said there was a double si
# permalink:   https://dunyanews.tv/index.php/en/Cricket/
jpg
# category:    IT-Science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          22
# title:       Ammonia and paper: Sustainability ideas at CES tech show
# description: LAS VEGAS (AFP) - The CES tech show has its share of gadgets that may be clutter
# permalink:   https://dunyanews.tv/index.php/en/Technology/635850-Ammonia-and-paper-Sustainability-ideas-at-CES-tech-show
# channel:     Dunya
# image:       https://img.dunyanews.tv/news/2022/January/01-07-22/news_big_images/635850_51472156.jpg
# category:    IT-Science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          23
# title:       BMW's new iX Flow, a car with color changing feature
# description: (Web Desk): At the annual Consumer Electronics Show trade fair BMW showed off th
# permalink:   https://dunyanews.tv/index.php/en/Technology/635805-BMW-new-iX-Flow-car-color-changing-feature
# channel:     Dunya
# image:       https://img.dunyanews.tv/news/2022/January/01-06-22/news_big_images/635805_22218951.jpg
# category:    IT-Science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          24
# title:       Robot tractors may be heading to some US farms
# description: LAS VEGAS (AFP) - Driverless plows and autonomous tools to weed vegetable plots
# permalink:   https://dunyanews.tv/index.php/en/Technology/635721-Robot-tractors-may-be-heading-to-some-US-farms
# channel:     Dunya
# image:       https://img.dunyanews.tv/news/2022/January/01-06-22/news_big_images/635721_83666186.jpg
# category:    IT-Science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          25
# title:       Khusro Bakhtiar rules out shortage of urea in country
# description: ISLAMABAD (Dunya News) - Minister for Industries and Production Khusro Bakhtiar
# permalink:   https://dunyanews.tv/index.php/en/Business/635883-Khusro-Bakhtiar-rules-out-shortage-of-urea-in-country
# channel:     Dunya
# image:       https://img.dunyanews.tv/news/2022/January/01-07-22/news_big_images/635883_13169382.jpg
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          26
# title:       Govt taking steps to bring improvement in manufacturing sector: Khusro
# description: ISLAMABAD (Web Desk) - Federal Minister for Industries and Production, Makhdum K
# permalink:   https://dunyanews.tv/index.php/en/Business/635874-Govt-taking-steps-to-bring-improvement-in-manufacturing-sector-Khusro
# channel:     Dunya
# image:       https://img.dunyanews.tv/news/2022/January/01-07-22/news_big_images/635874_23170986.jpg
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          27
# title:       Asian markets mixed as attention turns to US jobs
# description: HONG KONG (AFP) - Asian equities were mixed Friday as investors battled to insti
# permalink:   https://dunyanews.tv/index.php/en/Business/635847-Asian-markets-mixed-as-attention-turns-to-US-jobs
# channel:     Dunya
# image:       https://img.dunyanews.tv/news/2022/January/01-07-22/news_big_images/635847_86445175.jpg
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          28
# title:       Asad reaffirms govt's commitment to reduce gender disparity
# description: ISLAMABAD (Dunya News) – Minister for Planning Development and Special Initiativ
# permalink:   https://dunyanews.tv/index.php/en/Business/635813-Asad-reaffirms-govt-commitment-to-reduce-gender-disparity
# channel:     Dunya
# image:       https://img.dunyanews.tv/news/2022/January/01-06-22/news_big_images/635813_82801487.jpg
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          29
# title:       PSX gains 325.59 points to close at 45,082.30 points
# description: ISLAMABAD (Dunya News) – The KSE 100-index of the Pakistan Stock Exchange (PSX)
# permalink:   https://dunyanews.tv/index.php/en/Business/635811-PSX-gains-325.59-points-to-close-at-45,082.30-points-
# channel:     Dunya
# image:       https://img.dunyanews.tv/news/2022/January/01-06-22/news_big_images/635811_17603380.jpg
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          30
# title:       Europe stocks sink after Fed signals faster rate hikes
# description: LONDON (AFP) - European equities sank Thursday at the open after the Federal Res
# permalink:   https://dunyanews.tv/index.php/en/Business/635768-Europe-stocks-sink-after-Fed-signals-faster-rate-hikes
# channel:     Dunya
# image:       https://img.dunyanews.tv/news/2022/January/01-06-22/news_big_images/635768_58282183.jpg
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
# total news scraped page : 30

# %%
try:
    sources8 = [
                ["https://www.bolnews.com/sports", "Sports", "Bol"],
                ["https://www.bolnews.com/international/", "International", "Bol"],
                ["https://www.bolnews.com/health/", "Health", "Bol"],
                ["https://www.bolnews.com/entertainment/", "Entertainment", "Bol"],
                ["https://www.bolnews.com/technology/", "IT-Science", "Bol"],
                ["https://www.bolnews.com/business/","Business","Bol"]
                ]
    if Bol == True:
        counter = 0
        print('Getting Bol News...')
        i = 1
        permalinkArrayBolNews = []
        for source in sources8:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='catesquarebox'):
                if i <= 6:
                    try:
                        permalink = div.a['href']
                        permalinkArrayBolNews.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArrayBolNews
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for main in soup.find_all('main'):
                try:
                    detail_title = main.article.find('div',class_='headingsec').h1.text
                except:
                    detail_title = ''

                try:
                    if('https' in main.article.find('figure',class_='featuredimg').img['src']):
                        high_resolution_image = main.article.find('figure',class_='featuredimg').img['src']

                    else:
                        high_resolution_image = 'https://bolnews.s3.amazonaws.com/' + main.find('article',class_='infinite-post active').find('figure',class_='featuredimg').img['src']

                except:
                    high_resolution_image = ''
                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_all = main.article.find('div',class_='content').find_all('p')
                    detail_description = ''
                    for p in detail_description_all:
                        detail_description = detail_description + p.text.replace('\n','').replace('\xa0','')
                except:
                    detail_description = ''
                counter = counter + 1     
                language='English'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                            }
                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:80])
                    print('permalink:   ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])
# Out:
# Getting Bol News...
# total news found on listting page : 36
#
# No:          1
# title:
# description: MELBOURNE: The rapidly spreading Omicron variant, no Serena Williams or Roger Fe
# permalink:   https://www.bolnews.com/sports/2022/01/australian-open-threatening-to-become-not-so-happy-slam/
# channel:     Bol
# image:
# category:    Sports
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          2
# title:
# description: YAOUNDÉ: The Africa Cup of Nations begins in Cameroon on Sunday with the contine
# permalink:   https://www.bolnews.com/sports/2022/01/mane-salah-and-more-six-stars-to-watch-at-the-cup-of-nations/
# channel:     Bol
# image:
# category:    Sports
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          3
# title:
# description: CHRISTCHURCH: Ross Taylor saluted Bangladesh for their upset win in the first Te
# permalink:   https://www.bolnews.com/sports/2022/01/n-zealand-great-taylor-wants-winning-farewell-after-shock-loss/
# channel:     Bol
# image:
# category:    Sports
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          4
# title:
# description: SYDNEY: Wincing Ben Stokes produced a counter-punching half-century to help Engl
# permalink:   https://www.bolnews.com/sports/2022/01/stokes-defies-injury-with-fighting-half-century-in-ashes-test/
# channel:     Bol
# image:
# category:    Sports
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          5
# title:
# description: Abid Ali, the Pakistan cricket team’s Test opener, received permission to travel
# permalink:   https://www.bolnews.com/sports/2022/01/abid-ali-has-been-granted-permission-to-travel-from-karachi-to-lahore/
# channel:     Bol
# image:
# category:    Sports
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          6
# title:
# description: LAHORE: Khyber Pakhtunkhwa’s Abbas Ali has replaced Abdul Wahid Bangalzai in the
# permalink:   https://www.bolnews.com/sports/2022/01/abbas-ali-replaces-abdul-wahid-in-pakistan-u19-squad/
# channel:     Bol
# image:
# category:    Sports
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          7
# title:
# description: CAIRO, Jan. 7 (Xinhua) — Egypt seeks to learn from China’s “unique, distinguishe
# permalink:   https://www.bolnews.com/international/2022/01/interview-egypt-seeks-to-learn-from-chinas-unique-development-experience-official/
# channel:     Bol
# image:
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          8
# title:
# description: TAIPEI, Jan. 7 (Xinhua) — Taiwan reported four new locally-transmitted confirmed
# permalink:   https://www.bolnews.com/health/2022/01/taiwan-airport-cluster-infections-rise-to-12/
# channel:     Bol
# image:
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          9
# title:
# description: Sandra Bullock recently praised streaming services for fostering greater diversi
# permalink:   https://www.bolnews.com/amazing/2022/01/sandra-bullocks-were-all-praises-for-streaming-sites/
# channel:     Bol
# image:
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          10
# title:
# description: Experts have provided light on Prince William’s knee-jerk reaction to Prince Har
# permalink:   https://www.bolnews.com/entertainment/2022/01/prince-harry-and-prince-william-head-to-head-once-again/
# channel:     Bol
# image:
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          11
# title:
# description: The seventh international seminar of the Organisation of Islamic Cooperation (OI
# permalink:   https://www.bolnews.com/latest/2022/01/oic-seminar-urges-states-to-introduce-strong-anti-corruption-legislations/
# channel:     Bol
# image:
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          12
# title:
# description: AR Rehman is one of the highly recognized and loved singers in India. But, only
# permalink:   https://www.bolnews.com/bollywood/2022/01/the-song-highway-is-the-favorite-of-ar-rehman/
# channel:     Bol
# image:
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          13
# title:
# description: HONG KONG, Jan. 6 (Xinhua) — Hong Kong on Thursday reported 33 new cases of COVI
# permalink:   https://www.bolnews.com/health/2022/01/hong-kong-reports-33-new-covid-19-cases/
# channel:     Bol
# image:
# category:    Health
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          14
# title
# category:    IT-Science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          28
# title:
# description: The Nokia C100 is likely to cost Rs. 18,999 in Pakistan. On April 30, 2022, Noki
# permalink:   https://www.bolnews.com/technology/2022/01/nokia-c100-price-in-pakistan-specifications-release-date/
# channel:     Bol
# image:       https://bolnews.s3.eu-central-1.amazonaws.com/wp-content/uploads/2022/01/nokia_c100_c200_g100_g400_2760_android_authority_1641464561972.webp
# category:    IT-Science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          29
# title:
# description: If you’re looking to purchase a new iPhone in 2022, you’ll have a lot of alterna
# permalink:   https://www.bolnews.com/technology/2022/01/iphone-13-pro-vs-iphone-13-which-should-you-buy-in-2022/
# channel:     Bol
# image:
# category:    IT-Science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          30
# title:
# description: Google announced plans at CES 2022 to improve device connectivity for Android ph
# permalink:   https://www.bolnews.com/technology/2022/01/google-to-introduce-connectivity-features-for-smart-devices-in-2022/
# channel:     Bol
# image:
# category:    IT-Science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          31
# title:
# description: KARACHI: According to the Sarafa market, today’sgold rates in karachi (Pakistan)
# permalink:   https://www.bolnews.com/business/2022/01/gold-rates-todays-gold-rate-in-karachi-on-7th-january-2022/
# channel:     Bol
# image:       https://bolnews.s3.eu-central-1.amazonaws.com/wp-content/uploads/2022/01/02161806/Gold-Rates-in-Pakistan.jpg.webp
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          32
# title:
# description: KARACHI: The average customer rates of buying and selling of US dollar (USD) aga
# permalink:   https://www.bolnews.com/business/2022/01/usd-to-pkr-open-market-exchange-rates-on-7th-january-2022/
# channel:     Bol
# image:       https://bolnews.s3.eu-central-1.amazonaws.com/wp-content/uploads/2022/01/1-8.jpg-1.webp
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          33
# title:
# description: DUBAI:Employees and schoolchildren juggled work and studies with prayers on the
# permalink:   https://www.bolnews.com/business/2022/01/uae-works-on-friday-for-first-time/
# channel:     Bol
# image:
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          34
# title:
# description: KARACHI: The Power Cement Limited has signed an agreement to set up a 7MW solar
# permalink:   https://www.bolnews.com/business/2022/01/power-cement-burj-solar-energy-sign-deal-to-set-up-power-plant/
# channel:     Bol
# image:
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          35
# title:
# description: KARACHI: The average customer rates of buying and selling of Canadian Dollar (CA
# permalink:   https://www.bolnews.com/business/2022/01/cad-to-pkr-todays-canadian-dollar-to-pkr-exchange-rates-on-7th-jan-2022/
# channel:     Bol
# image:
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          36
# title:
# description: KARACHI: The average customer rates of buying and selling of Qatar Riyal (QAR) a
# permalink:   https://www.bolnews.com/business/2022/01/qar-to-pkr-todays-qatari-riyal-to-pkr-rates-on-7th-jan-2022/
# channel:     Bol
# image:
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
# total news scraped page : 36

# %%
try:
    sources22 = [
                ['https://abbtakk.tv/en/category/entertainment/','Entertainment','AbbTakk'],
                 ['https://abbtakk.tv/en/category/world/','International','AbbTakk'],
                 ['https://abbtakk.tv/en/category/pakistan/','National-local','AbbTakk'],
                 ['https://abbtakk.tv/en/category/sports/','Sports','AbbTakk'],
                ]
    if Abbtak == True:
        print('Getting Abbtakk News...')
        counter = 0
        i = 1
        permalinkArrayAbbtakNews = []
        for source in sources22:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for article in soup.find_all('article',class_='penci-imgtype-landscape'):
                if i <= 6:
                    try:
                        permalink = article.find('div', class_='entry-text').header.h2.a['href']
                        permalinkArrayAbbtakNews.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
                i = 1
        detail_source = permalinkArrayAbbtakNews
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for main in soup.find_all('main'):
                try:
                    detail_title = main.find('div',class_='entry-media').div.div.find('div',class_='penci-featured-col-1').div.div.h1.text
                except:
                    detail_title = ''

                try:
                    high_resolution_image
jpg
# category:    Sports
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          73
# title:       KP Lifts Quaid-e-Azam Trophy
# description: KARACHI: Khyber Pakhtunkhwa won the Quaid-e-Azam Trophy 2021-22, after defeating
# permalink:   https://abbtakk.tv/en/kp-lifts-quaid-e-azam-trophy/
# channel:     AbbTakk
# image:       https://abbtakk.s3.ap-southeast-1.amazonaws.com/en/wp-content/uploads/2021/12/30213613/KPK-768x422-1.jpg
# category:    Sports
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          74
# title:       Brisbane Heat Signs Fakhar Zaman for Big Bash League
# description: Canberra: Big Bash League outfit, Brisbane Heat has signed explosive Pakistani b
# permalink:   https://abbtakk.tv/en/brisbane-heat-signs-fakhar-zaman-for-big-bash-league/
# channel:     AbbTakk
# image:       https://abbtakk.s3.ap-southeast-1.amazonaws.com/en/wp-content/uploads/2021/12/30175130/Fakhar-Zaman-696x463-1.jpg
# category:    Sports
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          75
# title:       New Zealand’s Ross Taylor Announces Retirement From International Cricket
# description: WELLINGTON: New Zealand cricket icon Ross Taylor confirmed Thursday he is bowing
# permalink:   https://abbtakk.tv/en/new-zealands-ross-taylor-announces-retirement-from-international-cricket/
# channel:     AbbTakk
# image:       https://abbtakk.s3.ap-southeast-1.amazonaws.com/en/wp-content/uploads/2021/12/30163835/Untitled.png
# category:    Sports
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          76
# title:       PSL 2022: NCOC Allows 100pc Crowd
# description: ISLAMABAD: Following the government s official go-ahead, the Pakistan Super Leag
# permalink:   https://abbtakk.tv/en/psl-2022-ncoc-allows-100pc-crowd/
# channel:     AbbTakk
# image:       https://abbtakk.s3.ap-southeast-1.amazonaws.com/en/wp-content/uploads/2021/12/30003718/634812_74769193.jpg
# category:    Sports
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          77
# title:       PCB Decides To Appoint Five Coaches For National Team
# description: Lahore: The Pakistan Cricket Board (PCB) has decided to appoint five new coaches
# permalink:   https://abbtakk.tv/en/pcb-decides-to-appoint-five-coaches-for-national-team/
# channel:     AbbTakk
# image:       https://abbtakk.s3.ap-southeast-1.amazonaws.com/en/wp-content/uploads/2021/04/11232130/PCB.jpg
# category:    Sports
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          78
# title:       ICC Announces Nominees For Men’s Test Player Of The Year
# description: Dubai: The International Cricket Council (ICC) has announced the nominees for Me
# permalink:   https://abbtakk.tv/en/icc-announces-nominees-for-mens-test-player-of-the-year/
# channel:     AbbTakk
# image:       https://abbtakk.s3.ap-southeast-1.amazonaws.com/en/wp-content/uploads/2021/06/02215311/ICC-1.jpg
# category:    Sports
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          79
# title:       Day Three of Quaid-e-Azam Trophy Final Washed Out
# description: KARACHI: The third day of the Quaid-e-Azam Trophy final between Khyber Pakhtunkh
# permalink:   https://abbtakk.tv/en/day-three-of-quaid-e-azam-trophy-final-washed-out/
# channel:     AbbTakk
# image:       https://abbtakk.tv/en/wp-content/uploads/2018/03/National-Stadium-Karachi.jpg
# category:    Sports
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          80
# title:       Asia Cup U19: Pakistan Beat UAE To Reach Semi-Final
# description: DUBAI: Pakistan on Monday qualified for the semi-final after beating UAE by 21 r
# permalink:   https://abbtakk.tv/en/asia-cup-u19-pakistan-beat-uae-to-reach-semi-final/
# channel:     AbbTakk
# image:       https://abbtakk.s3.ap-southeast-1.amazonaws.com/en/wp-content/uploads/2021/12/27203444/1-3.jpg
# category:    Sports
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
# total news scraped page : 80

# %%
try:
    sources19 = [
                 ['https://92newshd.tv/category/pakistan','National-local','92News'],
                 ['https://92newshd.tv/category/sports','Sports','92News'],
                 ['https://92newshd.tv/category/Health','Health','92News'],
                 ['https://92newshd.tv/category/Entertainment','Entertainment','92News']
                ]
    if Ninetytwonews == True:
        counter = 0
        print('Getting 92 News...')
        i = 1
        permalinkArray92News = []
        for source in sources19:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='sub-posts'):
                if i <= 6:
                    try:
                        permalink = 'https://92newshd.tv' + div.a['href']
                        permalinkArray92News.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
                i = 1
        detail_source = permalinkArray92News
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='post-details'):
                try:
                    detail_title = div.h1.text

                except:
                    detail_title = ''

                try:
                    high_resolution_image = div.img['data-src']      
                except:
                    high_resolution_image = ''
                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_all = div.find('div',class_='content_detail').find_all('p')
                    detail_description = ''
                    for p in detail_description_all:
                        detail_description = detail_description + p.text
                except:
                    detail_description = ''
                counter = counter + 1 
                language='English'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                            }

                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:80])
                    print('permalink:   ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(coun
# category:    Entertainment
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
# total news scraped page : 48

# %%
try:
    sources15 = [
                 ['https://www.24newshd.tv/pakistan','Local','24NewsHD'],
                 ['https://www.24newshd.tv/world','International','24NewsHD'],
                 ['https://www.24newshd.tv/sports','Sports','24NewsHD'],
                 ['https://www.24newshd.tv/entertainment','Entertainment','24NewsHD'],
                 ['https://www.24newshd.tv/opinion','Blog','24NewsHD']
                ]
    if Twentyfournews == True:
        counter = 0
        print('Getting 24News Channel...')
        i = 1
        permalinkArray24News = []
        for source in sources15:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for article in soup.find_all('div',class_='category-post-block'):
                if i <= 6:
                    try:
                        permalink = article.div.div.a['href']
                        permalinkArray24News.append([permalink,source[1],source[2]])
                        counter = counter + 1
                        print(permalink)
                    except:
                        permalink = ''
                        print('exp')
                    i = i + 1
                i = 1
        detail_source = permalinkArray24News
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='detail-page'):
                try:
                    detail_title = div.h1.text

                except:
                    detail_title = ''

                try:
                    high_resolution_image = div.img['data-src']

                except:
                    high_resolution_image = ''
                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_all = div.find('div',class_='content_detail').find_all('p')
                    detail_description = ''
                    for p in detail_description_all:
                        detail_description = detail_description + p.text
                except:
                    detail_description = ''
                language='English'
                counter = counter + 1
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                }

                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:80])
                    print('permalink:   ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if False:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])

# %%
try:
    sources11 = [
                 ['https://gnnhd.tv/category/pakistan','National-local','GNN'],
                 ['https://gnnhd.tv/category/regional','National-local','GNN'],
                 ['https://gnnhd.tv/category/technology','IT-science','GNN'],
                 ['https://gnnhd.tv/category/business','Business','GNN']
                ]
    if Gnnnews == True:
        counter = 0
        i = 1
        print('Getting GNN News...')
        permalinkArrayGNNnews = []
        for source in sources11:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for a in soup.find('div',class_='mvp-feat5-small-sub').find_all('a'):
                if i <= 6:
                    try:
                        permalink = 'https://gnnhd.tv' + a['href']
                        permalinkArrayGNNnews.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
            for a in soup.find('div',class_='mvp-feat5-mid-sub-wrap').find_all('a'):
                if i <= 6:
                    try:
                        permalink = 'https://gnnhd.tv' + a['href']
                        permalinkArrayGNNnews.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArrayGNNnews
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',{'id':'mvp-post-main'}):
                try:
                    detail_title = div.header.h1.text
                except:
                    detail_title = ''

                try:
                    high_resolution_image = 'https://gnnhd.tv'+div.find('div',{'id':'mvp-post-feat-img'}).img['src'] 
                except:
                    high_resolution_image = ''
                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_all = div.find('div',{'id':'mvp-content-main'}).find_all('p')
                    detail_description = ''
                    for p in detail_description_all:
                        detail_description = detail_description + p.text
                except:
                    detail_description = ''
                counter = counter + 1
                language='English'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                }
                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:80])
                    print('permalink:   ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])
# Out:
# Getting GNN News...
# total news found on listting page : 40
#
# No:          1
# title:       Pakistan on course to appoint first female Supreme Court judge
# description: Islamabad: Pakistan's judicial commission confirmed the nomination of the first
# permalink:   https://gnnhd.tv/news/9044
# channel:     GNN
# image:       https://gnnhd.tv/media/12522/conversions/889548_9644738_Judges-start-saying-‘no’-to-govt-plots_akhbar-1280x720.webp
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          2
# title:       COVID-19: Pakistan reports 1,293 infections, six deaths
# description: Pakistan reported 1,293 new coronavirus infections, a new daily record, with aut
# permalink:   https://gnnhd.tv/news/9035
# channel:     GNN
# image:       https://gnnhd.tv/media/12499/conversions/thumbs_b_c_f5a496f42d7b1df2aadb3d76b1786f1f-1280x720.webp
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          3
# title:       November is still away, PM answers about another extension to Gen Bajwa
# description: When asked about giving another extension to Chief of Army Staff (COAS) General
# permalink:   https://gnnhd.tv/news/9034
# channel:     GNN
# image:       https://gnnhd.tv/media/12494/conversions/Imrankhan-1280x720.webp
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          4
# title:       Fawad suggests PML-N, PPP to replace names with ‘Sharifia’ and ‘Zardaria’
# description: Islamabad: Minister for Information and Broadcasting Fawad Chaudhry on Thursday
# permalink:   https://gnnhd.tv/news/9033
# channel:     GNN
# image:       https://gnnhd.tv/media/12491/conversions/fawad-1280x720.webp
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          5
# title:       Incumbent government taking roof from over the poor’s head: Bilawal
# description: Lahore: Pakistan Peoples’ Party (PPP) Chairman Bilawal Bhutto has said that the
# permalink:   https://gnnhd.tv/news/9031
# channel:     GNN
# image:       https://gnnhd.tv/media/12487/conversions/Bilawal-bhutto-1280x720.webp
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          6
# title:       Pakistan to host once again OIC session: FM Qureshi
# description: Islamabad: Pakistan will host once again Organisation of Islamic Cooperation (OI
# permalink:   https://gnnhd.tv/news/9030
# channel:     GNN
# image:       https://gnnhd.tv/media/12484/conversions/FM-Qureshi-1280x720.webp
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          7
# title:       International community’s help to Afghanistan imperative for regional peace: COAS
# description: Rawalpindi: Chief of Army Staff (COAS) General Qamar Javed Bajwa has said that t
# permalink:   https://gnnhd.tv/news/9057
# channel:     GNN
# image:       https://gnnhd.tv/media/12550/conversions/COAS-1280x720.webp
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          8
# title:       Pakistan to resolutely expose India’s anti-peace agenda: FO Spokesperson
# description: Islamabad: The Foreign Office Spokesperson Friday said Pakistan will continue to
# permalink:   https://gnnhd.tv/news/9055
# channel:     GNN
# image:       https://gnnhd.tv/media/12548/conversions/832245_6903763_FO_akhbar-1280x720.webp
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          9
# title:       Bad weather forces PIA to divert three Lahore-bound flights to Islamabad Airport
# description: Islamabad: Three domestic and international PIA flights were forced to land at I
# permalink:   https://gnnhd.tv/news/9050
# channel:     GNN
# image:       https://gnnhd.tv/media/12538/conversions/PIA-1280x720.webp
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          10
# title:       Issuing health cards is historic step towards Madina-like welfare state: Farrukh Habib
# description: Islamabad: Minister of State for Information and Broadcasting Farrukh Habib said
# permalink:   https://gnnhd.tv/news/9048
# channel:     GNN
# image:       https://gnnhd.tv/media/12530/conversions/Farruk-Habib-1280x720.webp
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          11
# title:       Seven killed, 40 injured in Khairpur Tamewali’s bus crash
# description: Bahawalpur: As many as seven people were killed and 40 were injured in a bus cra
# permalink:   https://gnnhd.tv/news/8916
# channel:     GNN
# image:       https://gnnhd.tv/media/12184/conversions/Accident-1280x720.webp
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          12
# title:       Public, private hospitals on Naya Pakistan Sehat Card panel increased from 43 to 150: CM Buzdar
# description: Lahore: Punjab Chief Minister (CM) Usman Buzdar has said that number of public a
# permalink:   https://gnnhd.tv/news/8864
# channel:     GNN
# image:       https://gnnhd.tv/media/12056/conversions/CM-1280x720.webp
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          13
# title:       Sindh decides to start new academic year from April 1, 2022
# description: Karachi: The Sindh Education Department has decided to start the new academic ye
# permalink:   https://gnnhd.tv/news/8863
# channel:     GNN
# image:       https://gnnhd.tv/media/12054/conversions/sindh-1280x720.webp
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          14
# title:       Mobile phones, currency notes showered in Sialkot’s unique wedding ceremony
# description: Sialkot: The guests have been welcomed amid showers of mobile phones and currenc
# permalink:   https://gnnhd.tv/news/8857
# channel:     GNN
# image:       https://gnnhd.tv/media/12038/conversions/unique-wedding-1280x720.webp
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          15
# title:       APP journalist Fawad Azam dies in Jaranwala road mishap
# description: Faisalabad: Senior journalist Fawad Azam Awan and his fellow villager died in a
# permalink:   https://gnnhd.tv/news/8832
# channel:     GNN
# image:       https://gnnhd.tv/media/11977/conversions/Fawad-Azam-1280x720.webp
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          16
# title:       159 Hindu pilgrims arrive in Pakistan, leave for Peshawar for religious rituals
# description: Lahore: As many 159 Hindu devotees arrived in Pakistan from India via Wagah bord
# permalink:   https://gnnhd.tv/news/8830
# channel:     GNN
# image:       https://gnnhd.tv/media/11966/conversions/Hindu-pilgrims-1280x720.webp
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          17
# title:       Lahore shivers as intermittent rain adds to winter chills
# description: Lahore: Rain in the provincial capital Lahore and its adjacent areas and other c
# permalink:   https://gnnhd.tv/news/9038
# channel:     GNN
# image:       https://gnnhd.tv/media/12510/conversions/499488_8381864_lahore2_akhbar-1280x720.webp
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          18
# title:       Two soldiers martyred, as many terrorists killed in KP operations
# description: Tank/South Waziristan: Two soldiers were martyred and as many terrorists killed
# permalink:   https://gnnhd.tv/news/8992
# channel:     GNN
# image:       https://gnnhd.tv/media/12392/conversions/Operation-1-1280x720.webp
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          19
# title:       SNGPL team unearths gas theft at CNG station; employees, vehicles attacked
# description: Kasur: A Sui Northern Gas Pipelines Limited employee suffered gunshot wound afte
# permalink:   https://gnnhd.tv/news/8987
# channel:     GNN
# image:       https://gnnhd.tv/media/12382/conversions/SNGPL-1280x720.webp
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          20
# title:       Four labourers die of suffocation in Karachi's garments factory
# description: Karachi: Four people died of suffocation in a factory near Chaukhandi Stop in Ka
# permalink:   https://gnnhd.tv/news/8919
# channel:     GNN
# image:       https://gnnhd.tv/media/12187/conversions/Factory-suffocation-1280x720.webp
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          21
# title:       Webb telescope fully deploys sunshield in mission milestone
# description: Washington: The James Webb Space Telescope fully deployed its tennis-court sized
# permalink:   https://gnnhd.tv/news/8976
# channel:     GNN
# image:       https://gnnhd.tv/media/12350/conversions/635575_18041216-1280x720.webp
# category:    IT-science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          22
# title:       Apple becomes world's first $3 trillion company
# description: Apple Inc has become the first company with a $3 trillion stock market value, li
# permalink:   https://gnnhd.tv/news/8924
# channel:     GNN
# image:       https://gnnhd.tv/media/12201/conversions/8192-1280x720.webp
# category:    IT-science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          23
# title:       Tesla stock continues to rise following record vehicle deliveries in 2021
# description: Shares of Tesla continued to jump on Monday, a day after the electric vehicle co
# permalink:   https://gnnhd.tv/news/8907
# channel:     GNN
# image:       https://gnnhd.tv/media/12169/conversions/Tesla-1280x720.webp
# category:    IT-science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          24
# title:       Beware of this dangerous message on WhatsApp! Simple negligence could empty your bank accounts
# description: The latest WhatsApp scam called Rediroff.com can be used to rob users of confide
# permalink:   https://gnnhd.tv/news/8898
# channel:     GNN
# image:       https://gnnhd.tv/media/12142/conversions/Whatsapp-1280x720.webp
# category:    IT-science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          25
# title:       Tesla delivers almost 1 million cars globally
# description: Washington: Tesla said it delivered nearly one million vehicles in 2021, almost
# permalink:   https://gnnhd.tv/news/8885
# channel:     GNN
# image:       https://gnnhd.tv/media/12106/conversions/2995146-1308101891-1280x720.webp
# category:    IT-science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          26
# title:       Twitter permanently bans US Representative Marjorie Taylor Greene
# description: Washington: Twitter on Sunday said it permanently banned the personal account of
# permalink:   https://gnnhd.tv/news/8872
# channel:     GNN
# image:       https://gnnhd.tv/media/12076/conversions/Twitter-1280x720.webp
# category:    IT-science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          27
# title:       Apple sued over cosy search partnership with Google
# description: Google’s deal with Apple, which ensures that it remains the default search engin
# permalink:   https://gnnhd.tv/news/9016
# channel:     GNN
# image:       https://gnnhd.tv/media/12443/conversions/fjgyjktu-1280x720.webp
# category:    IT-science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          28
# title:       France fines Google, Facebook $237 million over ‘cookies’
# description: Paris: French regulators have hit Google and Facebook with 210 million euros ($2
# permalink:   https://gnnhd.tv/news/9015
# channel:     GNN
# image:       https://gnnhd.tv/media/12441/conversions/FB-Google-1280x720.webp
# category:    IT-science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          29
# title:       Italian mafia fugitive caught after two decades, thanks to Google Maps
# description: Rome: Italian police has caught a top mafia fugitive who had been on the run for
# permalink:   https://gnnhd.tv/news/9003
# channel:     GNN
# image:       https://gnnhd.tv/media/12409/conversions/google-maps-ios-icon-1280x720.webp
# category:    IT-science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          30
# title:       Facebook removes Polish far-right political party account
# description: Warsaw: Facebook on Wednesday suspended the account of the Polish far-right part
# permalink:   https://gnnhd.tv/news/8990
# channel:     GNN
# image:       https://gnnhd.tv/media/12386/conversions/facebook-1280x720.webp
# category:    IT-science
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          31
# title:       Gold price increases in Pakistan
# description: Karachi: The gold price on Wednesday increased by Rs100 per tola to Rs126,250 in
# permalink:   https://gnnhd.tv/news/8996
# channel:     GNN
# image:       https://gnnhd.tv/media/12396/conversions/GOld-1280x720.webp
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          32
# title:       Apple becomes first company to hit $3 trillion market value, then slips
# description: San Francisco: Apple Inc on Monday became the first company to hit a $3 trillion
# permalink:   https://gnnhd.tv/news/8962
# channel:     GNN
# image:       https://gnnhd.tv/media/12311/conversions/202-1280x720.webp
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          33
# title:       Pakistani rupee continues to slide against US dollar
# description: Karachi: The Pakistani rupee continued to lose ground and fell to Rs176.75 again
# permalink:   https://gnnhd.tv/news/8948
# channel:     GNN
# image:       https://gnnhd.tv/media/12276/conversions/Dollar-1280x720.webp
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          34
# title:       Toyota overthrows GM to become US top-selling automaker in 2021
# description: Toyota Motor has dethroned General Motors as America’s top-selling automaker in
# permalink:   https://gnnhd.tv/news/8947
# channel:     GNN
# image:       https://gnnhd.tv/media/12274/conversions/Toyota-1280x720.webp
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          35
# title:       Gold price declines in Pakistan
# description: Karachi: Gold prices in Pakistan recorded a decline of Rs150 per tola and Rs129
# permalink:   https://gnnhd.tv/news/8944
# channel:     GNN
# image:       https://gnnhd.tv/media/12267/conversions/GOld-1280x720.webp
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          36
# title:       Apple becomes first American company to hit $3 trillion market cap
# description: Apple briefly hit a market cap of $3 trillion during intraday trading on Monday,
# permalink:   https://gnnhd.tv/news/8917
# channel:     GNN
# image:       https://gnnhd.tv/media/12185/conversions/Apple-1-1280x720.webp
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          37
# title:       Asian markets mixed as attention turns to US jobs
# description: Hong Kong: Asian equities were mixed Friday as investors battled to instigate a
# permalink:   https://gnnhd.tv/news/9039
# channel:     GNN
# image:       https://gnnhd.tv/media/12511/conversions/635847_86445175-1280x720.webp
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          38
# title:       Gold price decreases in Pakistan
# description: Karachi: The gold price on Thursday decreased by Rs100 per tola to Rs126,150 in
# permalink:   https://gnnhd.tv/news/9026
# channel:     GNN
# image:       https://gnnhd.tv/media/12467/conversions/GOld-1280x720.webp
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          39
# title:       US dollar continues to rise against Pakistani rupee
# description: Karachi: The Pakistani rupee continued to lose ground and fell to Rs176.92 again
# permalink:   https://gnnhd.tv/news/9023
# channel:     GNN
# image:       https://gnnhd.tv/media/12456/conversions/Dollar-1280x720.webp
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          40
# title:       Iranian airline launches direct flight from Mashad to Karachi
# description: Karachi: Iranian National Airline 'Iran Air' has launched its direct flight from
# permalink:   https://gnnhd.tv/news/9009
# channel:     GNN
# image:       https://gnnhd.tv/media/12427/conversions/169346274-1280x720.webp
# category:    Business
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
# total news scraped page : 40

# %%
try:
    sources9 = [
                 ['https://en.dailypakistan.com.pk/pakistan','National-local','DailyPakistan'],
                 ['https://en.dailypakistan.com.pk/sports','Sports','DailyPakistan'],
                 ['https://en.dailypakistan.com.pk/world','International','DailyPakistan'],
                 ['https://en.dailypakistan.com.pk/opinion','Blog','DailyPakistan'],
                 ['https://en.dailypakistan.com.pk/national','National-local','DailyPakistan'],
                 ['https://en.dailypakistan.com.pk/business','Business','DailyPakistan'],
                ]
    if Dailypakistan == True:
        print('Getting Daily Pakistan News...')
        i = 1
        counter = 0
        permalinkArrayDPnews = []
        for source in sources9:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='col-sm-6'):
                if i <= 6:
                    try:
                        permalink =  div.div.div.find('div',class_='tt-news-img').a['href']
                        permalinkArrayDPnews.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArrayDPnews
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',{'id':'mvp-post-main'}):
                try:
                    detail_title = div.header.h1.text
                except:
                    detail_title = ''

                try:
                    high_resolution_image = 'https://gnnhd.tv'+div.find('div',{'id':'mvp-post-feat-img'}).img['src'] 
                except:
                    high_resolution_image = ''
                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_all = div.find('div',{'id':'mvp-content-main'}).find_all('p')
                    detail_description = ''
                    for p in detail_description_all:
                        detail_description = detail_description + p.text
                except:
                    detail_description = ''
                counter = counter + 1
                language='English'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                }    
                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:80])
                    print('permalink:   ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if False:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])

# %%
try:
    sources18 = [
                 ['https://www.newsone.tv/pakistan-news','National-local','Newsone'],
                 ['https://www.newsone.tv/sports','Sports','Newsone'],
                 ['https://www.newsone.tv/world','International','Newsone'],
                 ['https://www.newsone.tv/blogs','Blog','Newsone'],
                 ['https://www.newsone.tv/entertainment','Entertainment','Newsone'],
                 ['https://www.newsone.tv/technology','IT-Science','Newsone'],
                 ['https://www.newsone.tv/lifestyle','Health','Newsone'],
                ]
    if True == True:
        print('Getting Newsone...')
        i = 1
        counter = 0
        permalinkArrayNewsOne = []
        for source in sources18:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for article in soup.find_all('div',class_='eq-blocks'):
                if i <= 6:
                    try:
                        permalink =  article.div.div.h2.a['href']
                        permalinkArrayNewsOne.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
            i = 1   
        detail_source = permalinkArrayNewsOne
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='single-page-tem'):
                try:
                    detail_title = div.section.div.div.h1.text
                except:
                    detail_title = ''

                try:
                    high_resolution_image = div.section.div.find('div', class_='single-post').find('div', class_='post-content').div.img['src'] 
                except:
                    high_resolution_image = ''
                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_all = div.section.div.find('div', class_='single-post').find('div', class_='post-content').article
                    detail_description = ''
                    for p in detail_description_all:
                        detail_description = detail_description + p.text
                except:
                    detail_description = ''
                counter = counter + 1
                language='English'
                values = {
                            'title': detail_title.strip(),
                            'description': detail_description.strip(),
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                }
                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description.strip()[0:80])
                    print('permalink:   ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])
# Out:
# Getting Newsone...
# exception in Newsone

# %%
try:
    sources10 = [
                 ['https://www.urdupoint.com/pakistan','National-local','Urdupoint'],
                 ['https://www.urdupoint.com/sports','Sports','Urdupoint'],
                 ['https://www.urdupoint.com/international','International','Urdupoint'],
                 ['https://www.urdupoint.com/showbiz','Entertainment','Urdupoint'],
                ]
    if Urdupoint == True:
        print('Getting Urdupoint News...')
        i = 1
        counter = 0
        permalinkArrayUrduPoint = []
        for source in sources10:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for a in soup.find('div',class_='list_hlaf_block').find_all('a'):
                if i <= 6:
                    try:
                        permalink = a['href']
                        permalinkArrayUrduPoint.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArrayUrduPoint
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',{'id':'main_content'}):
                try:
                    detail_title = div.find('div',class_='main_bar').div.h1.text
                except:
                    detail_title = ''

                try:
                    high_resolution_image = div.find('div',class_='news_article').find('div', class_='ac').picture.img['src']
                except:
                    high_resolution_image = ''
                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description = div.find('div',class_='main_bar').div.find('div',class_='detail_txt').a.text.replace('\n','').replace('\xa0','') + div.find('div',class_='main_bar').div.find('div',class_='detail_txt').text.replace('\n','').replace('\xa0','')
                except:
                    detail_description = ''
                counter = counter + 1
                language='Urdu'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                            }  

                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:80])
                    print('permalink:   ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])
# Out:
# Getting Urdupoint News...
# total news found on listting page : 24
#
# No:          1
# title:       پاکستان تحریک انصاف کی تنظیم سازی ، شاہ محمود قریشی کو اہم عہدہ مل گیا
# description:  پاکستان تحریک انصاف  اسلام آباد (اُردو پوائنٹ تازہ ترین اخبار۔ 07 جنوری 2022ء)
# permalink:   https://www.urdupoint.com/pakistan/news/islamabad/important-news/live-news-3011225.html
# channel:     Urdupoint
# image:
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          2
# title:
html
# channel:     Urdupoint
# image:       https://photo-cdn.urdupoint.com/show_img_new/daily/todayNewsLive/2022/420x350/pic_d280c_1641537335.jpg._2
# category:    Sports
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          13
# title:       کورونا کا پھیلاؤ خطرناک‘ سعودیہ میں مسلسل دوسرے روز 3000 سے زائد کیسز رپورٹ
# description:  سعودی عرب  ریاض ( اُردو پوائنٹ تازہ ترین اخبار ۔ 06 جنوری 2022ء )  سعودی عرب می
# permalink:   https://www.urdupoint.com/international/news-detail/saudi-arabia/riyadh/live-news-3010330.html
# channel:     Urdupoint
# image:       https://photo-cdn.urdupoint.com/show_img_new/daily/todayNewsLive/2020/420x350/pic_61138_1591793596.jpg._2
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          14
# title:       یو اے ای میں کورونا کا پھیلاؤ برقرار‘ یومیہ کیسز کی تعداد آج بھی 2600 سے نیچے نہ آئی
# description:  متحدہ عرب امارات  ابو ظہبی ( اُردو پوائنٹ تازہ ترین اخبار ۔ 06 جنوری 2022ء )  م
# permalink:   https://www.urdupoint.com/international/news-detail/uae/abu-dhabi/live-news-3010290.html
# channel:     Urdupoint
# image:       https://photo-cdn.urdupoint.com/show_img_new/daily/todayNewsLive/2022/420x350/pic_b578e_1641466646.jpg._2
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          15
# title:       عمان میں پاکستانیوں کیلئے روزگار کے مزید موقع پیدا ہونے کا امکان روشن ہوگیا
# description:  عمان  کراچی / مسقط ( اُردو پوائنٹ تازہ ترین اخبار ۔ 06 جنوری 2022ء ) خلیجی سلطن
# permalink:   https://www.urdupoint.com/international/news-detail/oman/muscat/live-news-3010241.html
# channel:     Urdupoint
# image:       https://photo-cdn.urdupoint.com/show_img_new/daily/todayNewsLive/2022/420x350/pic_0dfb2_1641463410.jpg._2
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          16
# title:       سعودیہ میں پکنک مناتے ہوئے آگ جلاتے وقت ایک بات ضرور ذہن میں رکھیں
# description:  سعودی عرب   ریاض ( اُردو پوائنٹ تازہ ترین اخبار ۔ 06 جنوری 2022ء )  سعودی عرب م
# permalink:   https://www.urdupoint.com/international/news-detail/saudi-arabia/riyadh/live-news-3010224.html
# channel:     Urdupoint
# image:       https://photo-cdn.urdupoint.com/show_img_new/daily/todayNewsLive/2022/420x350/pic_6e82b_1641462318.jpg._2
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          17
# title:       سعودی عرب میں گاڑیاں عنقریب ہائیڈروجن پر چلیں گی
# description:  سعودی عرب  ریاض ( اُردو پوائنٹ تازہ ترین اخبار ۔ 06 جنوری 2022ء )  سعودی عرب کی
# permalink:   https://www.urdupoint.com/international/news-detail/saudi-arabia/riyadh/live-news-3010190.html
# channel:     Urdupoint
# image:       https://photo-cdn.urdupoint.com/show_img_new/daily/todayNewsLive/2022/420x350/pic_f9b33_1641459278.jpg._2
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          18
# title:       دبئی ؛ گودام سے کباڑ چوری کرنے والے ایشیائی کارکن کو جیل کی سیر کرنا پڑ گئی
# description:  متحدہ عرب امارات  دبئی ( اُردو پوائنٹ تازہ ترین اخبار ۔ 06 جنوری 2022ء )  متحدہ
# permalink:   https://www.urdupoint.com/international/news-detail/uae/dubai/live-news-3010150.html
# channel:     Urdupoint
# image:       https://photo-cdn.urdupoint.com/show_img_new/daily/todayNewsLive/2022/420x350/pic_91853_1641456611.jpg._2
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          19
# title:       جاوید اختر کو مسلم خواتین کی فروخت کے ماسٹرمائنڈ کی حمایت مہنگی پڑگئی
# description:  بھارت  ممبئی(اُردو پوائنٹ اخبارتازہ ترین - آن لائن۔ 06 جنوری2022ء) مشہور شاعر ا
# permalink:   https://www.urdupoint.com/showbiz/news/3010433.html
# channel:     Urdupoint
# image:
# category:    Entertainment
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          20
# title:       سلمان خان نے محبت کا اظہار کر کے شادی سے انکار کردیا‘سومی علی
# description:  امریکی  ممبئی(اُردو پوائنٹ اخبارتازہ ترین - آن لائن۔ 06 جنوری2022ء) پاکستانی نژ
# permalink:   https://www.urdupoint.com/showbiz/news/3010434.html
# channel:     Urdupoint
# image:
# category:    Entertainment
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          21
# title:       اللہ کے راستے پر چلنے سے جو اطمینان اور لطف ملا ماضی کی زندگی اسکے مقابلے میں کچھ بھی نہیں ‘ رابی پیرزادہ
# description:  دنیا  لاہور (اُردو پوائنٹ اخبارتازہ ترین - آن لائن۔ 06 جنوری2022ء) سابقہ گلوکار
# permalink:   https://www.urdupoint.com/showbiz/news/3010435.html
# channel:     Urdupoint
# image:
# category:    Entertainment
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          22
# title:       زندگی میں مشکلات کا کا سامنا کرنا سیکھ لیا ہے ‘ حمیرا ارشد
# description:  شوبز  لاہور (اُردو پوائنٹ اخبارتازہ ترین - آن لائن۔ 06 جنوری2022ء) نامور گلوکار
# permalink:   https://www.urdupoint.com/showbiz/news/3010436.html
# channel:     Urdupoint
# image:
# category:    Entertainment
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          23
# title:       فیملی کی سپورٹ نہ ملتی تو کبھی بھی موجودہ مقام حاصل نہ کر سکتی ‘ ثنا جاوید
# description:  شوبز  لاہور (اُردو پوائنٹ اخبارتازہ ترین - آن لائن۔ 06 جنوری2022ء) اداکارہ ثنا
# permalink:   https://www.urdupoint.com/showbiz/news/3010437.html
# channel:     Urdupoint
# image:
# category:    Entertainment
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          24
# title:       انسان کو دنیا کیساتھ ساتھ آخرت میں بھی سر خرو ہونے کیلئے جدوجہد کرنی چاہیے ‘ افتخار ٹھاکر
# description:  دنیا  لاہور (اُردو پوائنٹ اخبارتازہ ترین - آن لائن۔ 06 جنوری2022ء) نامور کامیڈی
# permalink:   https://www.urdupoint.com/showbiz/news/3010438.html
# channel:     Urdupoint
# image:
# category:    Entertainment
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
# total news scraped page : 24

# %%
try:
    sources12 = [
                 ['https://www.neonetwork.pk/international','International','NeoNetwork'],
                 ['https://www.neonetwork.pk/blogs','Blog','NeoNetwork'],
                 ['https://www.neonetwork.pk/entertainment','Entertainment','NeoNetwork'],
                ]
    if Neonews == True:
        print('Getting Neo News...')
        i = 1
        permalinkArrayNeoNews = []
        for source in sources12:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='min_height_for_large_widget'):
                if i <= 6:
                    try:
                        permalink = div.article.div.a['href']
                        permalinkArrayNeoNews.append([permalink,source[1],source[2]])
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArrayNeoNews

        # for detail_page_source in detail_source:
        #     sourceHtml = requests.get(detail_page_source[0]).text
        #     soup = BeautifulSoup(sourceHtml, 'lxml')
        #     for div in soup.find_all('div',{'id':'main_content'}):
        #         try:
        #             detail_title = div.find('div',class_='main_bar').div.h1.text
        # #             
        #         except:
        #             detail_title = ''
        #             
        #         try:
        #             high_resolution_image = div.find('div',class_='main_bar').div.figure.img['src']
        #                        
        #         except:
        #             high_resolution_image = 'no-image'
        #         try:
        #             date_time = time.ctime()
        #         except:
        #             date_time = ''
        #         try:
        #             detail_description = div.find('div',class_='main_bar').div.find('div',class_='detail_txt').a.text.replace('\n','') + div.find('div',class_='main_bar').div.find('div',class_='detail_txt').text.replace('\n','')
        # #             print(description)
        # #             detail_description_all = div.find('div',class_='content_detail').find_all('p')
        # #             detail_description = ''
        # #             for p in detail_description_all:
        # #                 detail_description = detail_description + p.text
        #         except:
        #             
        #         language='Urdu'
        #         values = {
        #                     'title': detail_title,
        #                     'description': detail_description,
        #                     'date': date_time,
        #                     'channel': source[2],
        #                     'image': high_resolution_image,
        #                     'permalink': detail_page_source[0],
        #                     'category': detail_page_source[1],
        #                     'fetching_date': date.today(),
        #                     'no_of_comments': 0,
        #                     'rating': 0,
        #                     'language':language,
        #                     'created_at': date.today(),
        #                     'updated_at': date.today(),
        #                     'comments': [],
        #                     'resgistered_views':[],
        #                     'no_of_registered_views':0,
        #                     'no_of_nonregistered_views':0,
        #                     }
        #         
        #         print('----------------')       
            # if(developmentMode):
            #         data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
            #         
            #         response = requests.post(url, data=values)
            #         if response.status_code == 429:
            #             time.sleep(int(response.headers["Retry-After"]))
            #     else:
            #         data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
            #         url = "http://3.142.50.232:5000/api/news/all"
            #         response = requests.post(url, data=values)
            #         if response.status_code == 429:
            #             time.sleep(int(response.headers["Retry-After"]))

except:
    print('exception in ' + source[2])

# %%
try:
    sources20 = [
                 ['https://royalnews.tv/?cat=2','National-local','Royalnews'],
                 ['https://royalnews.tv/?cat=3','International','Royalnews'],
                 ['https://royalnews.tv/?cat=4','Sports','Royalnews'],
                 ['https://royalnews.tv/?cat=5','Entertainment','Royalnews'],    
                ]
    if Royal == True:
        print('Getting Royal News...')
        i = 1
        counter = 0
        permalinkArrayNeoNews = []
        for source in sources20:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for article in soup.find_all('article',class_='format-standard'):
                if i <= 6:
                    try:
                        permalink = article.header.h1.a['href']
                        permalinkArrayNeoNews.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
                i = 1
        detail_source = permalinkArrayNeoNews
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for article in soup.find_all('article',class_='format-standard'):
                try:
                    detail_title = article.header.h1.text
                except:
                    detail_title = ''

                try:
                    high_resolution_image = article.header['style'][15:-45]
                except:
                    high_resolution_image = 'no-image'
                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description = article.find('div',class_='entry-content').p.text
                except:
                    detail_description = ''
                counter = counter + 1
                language='Urdu'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                }        

                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:80])
                    print('permalink:   ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])
# Out:
# Getting Royal News...
# total news found on listting page : 40
#
# No:          1
# title:       لاہور سمیت پنجاب کے مختلف اضلاع میں کل سے اسکول کھل جائیں گے….
# description: لاہور: (رائل نیوز) لاہور سمیت پنجاب کے مختلف اضلاع میں کل سے اسکول کھل جائیں گے۔
# permalink:   https://royalnews.tv/?p=49006
# channel:     Royalnews
# image:       https://royalnews.tv/wp-content/uploads/2022/01/1-19.jpg
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          2
# title:       اومی کرون پر مسلسل نظریں مرکوز، لاک ڈاؤن کا ابھی فیصلہ نہیں کیا
# description: اسلام آبااد: (رائل نیوز) وفاقی وزیراسد عمر نے کہاہے کہ کورونا کی قسم اومی کرون
# permalink:   https://royalnews.tv/?p=49003
# channel:     Royalnews
# image:       https://royalnews.tv/wp-content/uploads/2022/01/1-18.jpg
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          3
# title:       کراچی میں دہشتگردی کا بڑا منصوبہ ناکام
# description: کراچی: (رائل  نیوز) کراچی کے علاقے کورنگی میں پولیس نے دہشتگردی کا بڑا منصوبہ نا
# permalink:   https://royalnews.tv/?p=49000
# channel:     Royalnews
# image:       https://royalnews.tv/wp-content/uploads/2022/01/1-17.jpg
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          4
# title:       تحریک انصاف کی سکروٹنی کمیٹی رپورٹ بارش کا پہلا قطرہ ہے
# description: لاہور: (رائل نیوز) پنجاب اسمبلی میں اپوزیشن لیڈر حمزہ شہبازشریف نے کہا ہے کہ تحر
# permalink:   https://royalnews.tv/?p=48997
# channel:     Royalnews
# image:       https://royalnews.tv/wp-content/uploads/2022/01/1-16.jpg
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          5
# title:       ملک میں پی ڈی ایم کی انتشار پھیلانے کی سیاست نہیں چلے گی
# description: لاہور: (رائل نیوز) وزیراعلیٰ عثمان بزدار نے کہا ہے کہ ملک میں پی ڈی ایم کی انتشا
# permalink:   https://royalnews.tv/?p=48994
# channel:     Royalnews
# image:       https://royalnews.tv/wp-content/uploads/2022/01/1-15.jpg
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          6
# title:       بلوچستان میں بارشوں سے تباہی
# description: کوئٹہ: (رائل نیوز) بلوچستان کے مکران ڈویژن میں بارشوں نے تباہی مچا دی ہے۔ گوادر
# permalink:   https://royalnews.tv/?p=48991
# channel:     Royalnews
# image:       https://royalnews.tv/wp-content/uploads/2022/01/1-14.jpg
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          7
# title:       وزیراعظم سے جھوٹی تقاریر، ٹویٹس پر استعفیٰ دینے کا مطالبہ
# description: لاہور: (رائل نیوز) مسلم لیگ ن کی ترجمان نے وزیراعظم سے جھوٹی تقاریر، ٹویٹس پر اس
# permalink:   https://royalnews.tv/?p=48988
# channel:     Royalnews
# image:       https://royalnews.tv/wp-content/uploads/2022/01/1-13.jpg
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          8
# title:       قوم کا پیسہ بچانے پر وزارت مواصلات مبارکباد کی مستحق
# description: اسلام آباد: (رائل نیوز) وزیراعظم عمران خان نے قوم کا پیسہ بچانے اور ن لیگ کی حک
# permalink:   https://royalnews.tv/?p=48985
# channel:     Royalnews
# image:       https://royalnews.tv/wp-content/uploads/2022/01/1-12.jpg
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          9
# title:       ملک بھر میں 24 گھنٹے کے دوران کورونا سے مزید 2 اموات
# description: اسلام آباد: (ویب ڈیسک) کورونا وائرس سے 2 افراد جاں بحق ہوگئے، جس کے بعد اموات ک
# permalink:   https://royalnews.tv/?p=48982
# channel:     Royalnews
# image:       https://royalnews.tv/wp-content/uploads/2022/01/635435_45612536.jpg
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          10
# title:       لاہور، اسلام آباد ،سمیت ملک کے مختلف شہروں میں بادل برس پڑے
# description: لاہور، اسلام آباد سمیت ملک کے مختلف شہروں میں بادل برس پڑے، آسمان سے برستی بوندو
# permalink:   https://royalnews.tv/?p=48979
# channel:     Royalnews
# image:       https://royalnews.tv/wp-content/uploads/2022/01/635448_71307302.jpg
# category:    National-local
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          11
# title:       ٹوئٹر نے امریکی کانگریس ویمن مرجوری ٹیلر کا اکاؤنٹ مستقل طور پر بند
# description: نیویارک :سماجی رابطے کی ویب سائٹ ٹوئٹر نے امریکی کانگریس ویمن مرجوری ٹیلر کا اکا
# permalink:   https://royalnews.tv/?p=48973
# channel:     Royalnews
# image:       https://royalnews.tv/wp-content/uploads/2022/01/1-11.jpg
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          12
# title:       نیدرزلینڈ: لاک ڈاؤن کیخلاف ہزاروں شہریوں کا احتجاج
# description: ایمسٹرڈیم: نیدرزلینڈ میں کورونا لاک ڈاؤن کے خلاف ہزاروں شہری سڑکوں پر نکل آئے،
# permalink:   https://royalnews.tv/?p=48970
# channel:     Royalnews
# image:       https://royalnews.tv/wp-content/uploads/2022/01/1-10.jpg
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          13
# title:       سوڈان: فوجی حکومت کیخلاف مظاہروں میں ہلاکتیں
# description: خرطوم:  سوڈان میں فوجی حکومت کے خلاف مظاہروں میں ہلاکتوں کے بعد وزیراعظم عبداللہ
# permalink:   https://royalnews.tv/?p=48967
# channel:     Royalnews
# image:       https://royalnews.tv/wp-content/uploads/2022/01/1-9.jpg
# category:    International
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
# exception in Royalnews

# %%
try:
    sources23 = [
                 ['https://mashion.pk/category/mashup/fashion/','Fashion','Mashion'],
                 ['https://mashion.pk/category/mashup/celebrity/','Entertainment','Mashion'],    
                ]
    if Mashion == True:
        counter = 0
        print('Getting Mashion(showbiz) News...')
        i = 1
        permalinkArrayNeoNews = []
        for source in sources23:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='large-4'):
                if i<= 6:
                    try:
                        permalink = div.h2.a['href']
                        permalinkArrayNeoNews.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArrayNeoNews
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find('div',{'id':'content'}):
                try:
                    detail_title = div.div.find('div',class_='title').h1.text
                except:
                    detail_title = ''
                try:
                    high_resolution_image = div.div.div['data-bg'][4:-1]
                except:
                    high_resolution_image = ''
                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description = soup.find('div', class_='wpb_wrapper').div.div.p.text
                except:
                    detail_description = ''
                counter = counter + 1
                language='Urdu'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                }

                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:80])
                    print('permalink:     ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
                break
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])
# Out:
# Getting Mashion(showbiz) News...
# total news found on listting page : 0
# total news scraped page : 0

# %%
try:
    sources24 = [
                 ['https://www.mangobaaz.com/recents','Blog','Mangobaaz'],
                 ['https://www.mangobaaz.com/category/showsha','Blog','Mangobaaz'],    
                ]
    if Mangobaaz == True:
        print('Getting Mangobaaz News...')
        i = 1
        counter = 0
        permalinkArrayMangobaaz = []
        for source in sources24:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')

            for a in soup.find_all('a',class_='block focus:outline-none'):
                if i <= 6:
                    try:
                        permalink ='https://www.mangobaaz.com' + a['href']
                        permalinkArrayMangobaaz.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArrayMangobaaz
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div', class_='leading-normal'):
                try:
                    detail_title = div.main.h1.text
                except:
                    detail_title = ''
                try:
                    high_resolution_image = div.div['style'][21:-2]
                except:
                    high_resolution_image = ''
                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description = div.main.article.p.text
                except:
                    detail_description = ''
                counter = counter + 1
                language='English'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                }  

                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:80])
                    print('permalink:     ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter)) 
except:
    print('exception in ' + source[2])
# Out:
# Getting Mangobaaz News...
# total news found on listting page : 12
#
# No:          1
# title:       Proton Pakistan Partners With Euro Oil To Launch Proton Genuine Oil
# description: Al-Haj Automotive Pvt Ltd. – the progressive assembler and distributor of Proton
# permalink:     https://www.mangobaaz.com/proton-pakistan-partners-with-euro-oil-to-launch-proton-genuine-oil
# channel:     Mangobaaz
# image:       https://cdn.mangobaaz.com/wp-content/uploads/2022/01/pririrriir.jpg
# category:    Blog
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          2
# title:       Premium Quality Fast Fashion That Won't Break The Bank – Dresscode’s Biggest Offer Yet!
# description: It’s here! The greatest 100% cashback offer and sale of the season. Can you imag
# permalink:     https://www.mangobaaz.com/premium-quality-fast-fashion-that-wont-break-the-bank-dresscodes-biggest-offer-yet
# channel:     Mangobaaz
# image:       https://cdn.mangobaaz.com/wp-content/uploads/2021/12
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
# total news scraped page : 12

# %%
try:
    sources25 = [
                 ['https://www.hellopakistanmag.com/fashion','Fashion','HelloPakistanMagazine'],
                 ['https://www.hellopakistanmag.com/entertainment','Entertainment','HelloPakistanMagazine'],
                ]
    if Hellopakistanmag == True:
        print('Getting HelloPakistanMagazine News...')
        i = 1
        counter = 0
        permalinkArrayHelloPakistanMag = []
        for source in sources25:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='col-md-6'):
                if i<= 6:
                    try:
                        permalink = div.find('div',class_='featured-content').a['href']
                        permalinkArrayHelloPakistanMag.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArrayHelloPakistanMag
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='article-content'):
                try:
                    detail_title = div.h3.text
                except:
                    detail_title = ''
                try:
                    high_resolution_image = div.find('div',class_='article-image').img['src']
                except:
                    high_resolution_image = ''

                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_all = div.find_all('p')
                    detail_description = ''
                    for p in detail_description_all:
                        detail_description = detail_description + p.text.replace('\xa0','')
                except:
                    detail_description = ''
                counter = counter + 1
                language='English'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                }  
                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:80])
                    print('permalink:     ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])
# Out:
# Getting HelloPakistanMagazine News...
# total news found on listting page : 12
#
# No:          1
# title:       SHAADI SEASON 101: DID YOU KNOW THERE ARE 8 HENNA ‘CUISINES’?
# description:  Henna, also referred to as mehndi in the Indian subcontinent is a type of body
# permalink:     https://www.hellopakistanmag.com/03-Jan-2022/shaadi-season-101-did-you-know-there-are-8-henna-cuisines
# channel:     HelloPakistanMagazine
# image:       https://www.hellopakistanmag.com/digital_images/large/2022-01-03/shaadi-season-101-did-you-know-there-are-8-henna-cuisines-1641223010-1581.jpeg
# category:    Fashion
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          2
# title:       2021’S MOST LOVED BRIDAL LOOKS
# description:  Despite the ongoing pandemic, many celebrities went forward with their weddings
# permalink:     https://www.hellopakistanmag.com/31-Dec-2021/2021-s-most-loved-bridal-looks
# channel:     HelloPakistanMagazine
# image:       https://www.hellopakistanmag.com/digital_images/large/2021-12-31/2021-s-most-loved-bridal-looks-1640905841-5782.jpeg
# category:    Fashion
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          3
# title:       All eyes on Pantene’s Hair Show at this year’s #PHBCW
# description: The 19th Pantene Hum Bridal Couture Week took place in a very chilly Lahore from
# permalink:     https://www.hellopakistanmag.com/25-Dec-2021/all-eyes-on-pantene-s-hair-show-at-this-year-s-phbcw
# channel:     HelloPakistanMagazine
# image:       https://www.hellopakistanmag.com/digital_images/large/2021-12-25/all-eyes-on-pantene-s-hair-show-at-this-year-s-phbcw-1640450337-5771.jpeg
# category:    Fashion
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          4
# title:       RECONNECTING WITH OUR ROOTS: INTERNATIONAL DESIGNER ALI HAIDER DAWNS HIS CREATIVE VISION IN PAKISTAN
# description:  The clothing I created in Pakistan will celebrate the heritage and craftsmanshi
# permalink:     https://www.hellopakistanmag.com/21-Dec-2021/reconnecting-with-our-roots-international-designer-ali-haider-dawns-his-creative-vision-in-pakistan
# channel:     HelloPakistanMagazine
# image:       https://www.hellopakistanmag.com/digital_images/large/2021-12-21/reconnecting-with-our-roots-international-designer-ali-haider-dawns-his-creative-vision-in-pakistan-1640067333-1248.jpeg
# category:    Fashion
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          5
# title:       WHAT IS 'A REAL MODEL'? FT. DUBAI-BASED PAKISTANI MODEL HAMZA SALAH
# description:  I’m a real model - by that I mean I’m a real person. My life is all about inspi
# permalink:     https://www.hellopakistanmag.com/16-Dec-2021/what-is-a-real-model-ft-dubai-based-pakistani-model-hamza-salah
# channel:     HelloPakistanMagazine
# image:       https://www.hellopakistanmag.com/digital_images/large/2021-12-16/what-is-a-real-model-ft-dubai-based-pakistani-model-hamza-salah-1639667416-3437.jpeg
# category:    Fashion
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          6
# title:       Khaadi is Wild About you and the New Experience Hub proves it
# description: Karachi, 3 December: Khaadi stuns everyone once again by taking the lead as Paki
# permalink:     https://www.hellopakistanmag.com/15-Dec-2021/khaadi-is-wild-about-you-and-the-new-experience-hub-proves-it
# channel:     HelloPakistanMagazine
# image:       https://www.hellopakistanmag.com/digital_images/large/2021-12-15/khaadi-is-wild-about-you-and-the-new-experience-hub-proves-it-1639566158-2785.jpeg
# category:    Fashion
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          7
# title:       IMTISAL ZAFAR: THE MAN, THE MYTH, THE LEGEND REVAMPING ART & E-MUSIC
# description:  A proponent of artistic revamping, Imtisal Zafar is renowned for three power pa
# permalink:     https://www.hellopakistanmag.com/04-Jan-2022/imtisal-zafar-the-man-the-myth-the-legend-revamping-art-e-music
# channel:     HelloPakistanMagazine
# image:       https://www.hellopakistanmag.com/digital_images/large/2022-01-04/imtisal-zafar-the-man-the-myth-the-legend-revamping-art-e-music-1641307632-1700.jpeg
# category:    Entertainment
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          8
# title:       HIP HOP IN PAKISTAN: WHAT’S POPPIN’?
# description:  Through the 2000s, the rap songs were mostly in English and Punjabi. We saw ban
# permalink:     https://www.hellopakistanmag.com/03-Jan-2022/hip-hop-in-pakistan-what-s-poppin
# channel:     HelloPakistanMagazine
# image:       https://www.hellopakistanmag.com/digital_images/large/2022-01-03/hip-hop-in-pakistan-what-s-poppin-1641224870-4778.jpeg
# category:    Entertainment
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          9
# title:       SEVEN CELEBRITY STATEMENTS SWORN TO BACKLASH IN 2021
# description:  Surely, fans pick up everything celebrities say, but sometimes the response sti
# permalink:     https://www.hellopakistanmag.com/02-Jan-2022/seven-celebrity-statements-sworn-to-backlash-in-2021
# channel:     HelloPakistanMagazine
# image:       https://www.hellopakistanmag.com/digital_images/large/2022-01-02/seven-celebrity-statements-sworn-to-backlash-in-2021-1641145704-2262.jpeg
# category:    Entertainment
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          10
# title:       TO THE FORGOTTEN PARTITION: HUM TV’S KHWAB TOOT JATE HAIN HIGHLIGHTS EAST AND WEST PAKISTAN’S
# description:  Stories like Dastaan and Aangan have made waves on television, educating the ma
# permalink:     https://www.hellopakistanmag.com/02-Jan-2022/to-the-forgotten-partition-hum-tv-s-khwab-toot-jate-hain-highlights-east-and-west-pakistan-s
# channel:     HelloPakistanMagazine
# image:       https://www.hellopakistanmag.com/digital_images/large/2022-01-02/to-the-forgotten-partition-hum-tv-s-khwab-toot-jate-hain-highlights-east-and-west-pakistan-s-1641144230-2291.jpg
# category:    Entertainment
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          11
# title:       A - LISTERS SPILL THE TEA ON MOMINA’S MIXED PLATE
# description:  The latest episodes of Momina’s Mixed Plate featured some of the hottest supers
# permalink:     https://www.hellopakistanmag.com/31-Dec-2021/a-listers-spill-the-tea-on-momina-s-mixed-plate
# channel:     HelloPakistanMagazine
# image:       https://www.hellopakistanmag.com/digital_images/large/2021-12-31/a-listers-spill-the-tea-on-momina-s-mixed-plate-1640964915-7236.jpg
# category:    Entertainment
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          12
# title:       BREAKTHROUGH TV DRAMA DEBUTS IN 2021
# description:  2021 was exceptional in terms of the drama we got to watch; we had a wide range
# permalink:     https://www.hellopakistanmag.com/31-Dec-2021/breakthrough-tv-drama-debuts-in-2021
# channel:     HelloPakistanMagazine
# image:       https://www.hellopakistanmag.com/digital_images/large/2021-12-31/breakthrough-tv-drama-debuts-in-2021-1640907115-1418.jpeg
# category:    Entertainment
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
# total news scraped page : 12

# %%
try:
    sources24 = [
                 ['https://sunday.com.pk/category/fashion/','Fashion','SundayNews'],
                 ['https://sunday.com.pk/category/fashion/fashion-news/','Fashion','SundayNews'],
                 ['https://sunday.com.pk/category/fashion/best-dressed/','Fashion','SundayNews'],
                 ['https://sunday.com.pk/category/fashion/fashion-shoot/','Fashion','SundayNews'],
                 ['https://sunday.com.pk/category/fashion/fashion-week/','Fashion','SundayNews'],
                 ['https://sunday.com.pk/category/fashion/look-of-the-day/','Fashion','SundayNews'],
                 ['https://sunday.com.pk/category/fashion/style-jury/','Fashion','SundayNews'],
                 ['https://sunday.com.pk/category/lifestyle/food/','Gourmet','SundayNews'],
                ]
    if Sunday == True:
        print('Sunday News...')
        i = 1
        counter = 0
        permalinkArraySundaynews = []
        for source in sources24:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='post'):
                if i<= 6:
                    try:
                        permalink = div.find('div',class_='row').find('div',class_='medium-7').div.find('div',class_='post-title').h5.a['href']
                        permalinkArraySundaynews.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArraySundaynews
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for article in soup.find_all('article'):
                try:
                    detail_title = article.find('div',class_='post-title-container').header.h1.text.replace('\t','').replace('\n','')   
                except:
                    detail_title = 'pakteki'
                try:
                    high_resolution_image = article.find('div',class_='thb-article-featured-image').img['data-src']

                except:
                    high_resolution_image = 'pakteki'

                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_all = article.find('div',class_='thb-post-share-container').find('div',class_='post-content-container').find('div',class_='post-content').find_all('p')
                    detail_description = ''
                    for p in detail_description_all:
                        detail_description = detail_description + p.text.replace('\xa0','')
                except:
                    detail_description = 'pakteki'
                counter = counter + 1
                language='English'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                }  
                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:80])
                    print('permalink:     ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])
# category:    Gourmet
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          33
# title:       8 Picks From The World Of Fashion, Food And Lifestyle Sunday Editors Are Hooked On
# description: Want to know what Sunday Editors are currently hooked on these days? We’re gushi
# permalink:     https://sunday.com.pk/editors-pick/8-picks-from-the-world-of-fashion-food-and-lifestlye-sunday-editors-are-hooked-on/
# channel:     SundayNews
# image:       https://sunday.com.pk/wp-content/uploads/2021/12/WhatsApp-Image-2021-12-21-at-4.48.30-PM.jpeg
# category:    Gourmet
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          34
# title:       “Gaia” Japanese Fine-Dining Restaurant Opens in Islamabad Written by Humay Waseeem
# description: Historically, Japanese restaurants have been a novelty in Islamabad, but in the
# permalink:     https://sunday.com.pk/lifestyle/food/gaia-japanese-fine-dining-restaurant-opens-in-islamabad-written-by-humay-waseeem/
# channel:     SundayNews
# image:       https://sunday.com.pk/wp-content/uploads/2021/08/QAP_3660-1.jpg
# category:    Gourmet
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          35
# title:       Our Fav New Japanese Food Joint – Saku Hana
# description: Let’s address the talk of the town today – Saku Hana, the new Japanese style
# res
# permalink:     https://sunday.com.pk/lifestyle/our-fav-new-japanese-food-joint-saku-hana/
# channel:     SundayNews
# image:       https://sunday.com.pk/wp-content/uploads/2021/04/Saku-hana-web.jpg
# category:    Gourmet
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          36
# title:       Here’s What’s New at ETH
# description: Every Lahori and Islooite knows of, loves and frequently visits English Tea Hous
# permalink:     https://sunday.com.pk/lifestyle/heres-whats-new-at-eth/
# channel:     SundayNews
# image:       https://sunday.com.pk/wp-content/uploads/2021/02/ETH-web.jpg
# category:    Gourmet
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
#
# No:          37
# title:       Bakery delights by Chashni
# description: After introducing mithai in the true traditional form representing our culture a
# permalink:     https://sunday.com.pk/lifestyle/bakery-delights-by-chashni/
# channel:     SundayNews
# image:       https://sunday.com.pk/wp-content/uploads/2021/02/Chashni-web.jpg
# category:    Gourmet
# -----------------------------------------------
# inserted in DB
# -----------------------------------------------
# total news scraped page : 37

# %%
try:
    sources27 = [
        ["https://www.zaiqa.com/recipes/pakistani/","Gourmet","Zaiqatv"],
        ["https://www.zaiqa.com/recipes/sweets-desserts/","Gourmet","Zaiqatv"],
        ["https://www.zaiqa.com/recipes/masala-tv/","Gourmet","Zaiqatv"],
        ["https://www.zaiqa.com/recipes/indian/","Gourmet","Zaiqatv"],
        ["https://www.zaiqa.com/recipes/zaiqa-tv/","Gourmet","Zaiqatv"],
    ]
    if Zaiqa == True:
        print('Getting Zaiqa News...')
        i = 1
        counter = 0
        permalinkArrayZaiqa = []
        for source in sources27:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for li in soup.find_all('li',class_='group'):
                if i <= 6:
                    try:
                        permalink = source[0][:-19] + li.a['href']
                        permalinkArrayZaiqa.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArrayZaiqa
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for a in detail_source:
            print(a)
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='recipes'):
                try:
                    detail_title = div.h1.text
                except:
                    detail_title = ''
                try:
                    high_resolution_image = ''
                except:
                    high_resolution_image = ''

                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_all = div.find('div',class_='recipebox').ul.find_all('li')
                    detail_description_ingredients = ''
                    for li in detail_description_all:
                        detail_description_ingredients = detail_description_ingredients + ' ' + li.text.replace('\xa0','')
                    detail_description = div.find('div',class_='recipebox').h2.text + ':' + detail_description_ingredients
                except:
                    detail_description = ''
                counter = counter + 1
                language='English'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                }  
                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:20])
                    print('permalink:     ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])

# %%
try:
    sources16 = [
        ["https://www.city42.tv/district-government","National-local","city42"],
        ["https://www.city42.tv/blog","Blog","city42"],
        ["https://www.city42.tv/lahore","National-local","city42"],
        ["https://www.city42.tv/government-of-punjab","National-local","city42"],     
    ] 
    if City42 == True:
        print('Getting Mashion(showbiz) News...')
        i = 1
        counter = 0
        permalinkArrayCity42 = []
        for source in sources16:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='row'):
                if i <= 6:
                    try:
                        permalink = div.div.article.find('div',class_='zm-post-dis').div.h2.a['href']
                        permalinkArrayCity42.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArrayCity42
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='recipes'):
                try:
                    detail_title = div.h1.text

                except:
                    detail_title = ''
                try:
                    high_resolution_image = ''

                except:
                    high_resolution_image = ''

                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_all = div.find('div',class_='articles').find_all('p')
                    detail_description = ''
                    for p in detail_description_all:
                        detail_description = detail_description + p.text.replace('\xa0','')
                except:
                    detail_description = ''
                counter = counter + 1
                language='English'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                }  
                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:20])
                    print('permalink:     ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])

# %%
try:
    sources28 = [
                  ['https://www.urdunews.com/sections/%D9%BE%D8%A7%DA%A9%D8%B3%D8%AA%D8%A7%D9%86','National-local','Urdunews'],
                  ['https://www.urdunews.com/sections/%D8%AF%D9%86%DB%8C%D8%A7','International','Urdunews'],
                  ['https://www.urdunews.com/sections/%D8%B4%D9%88%D8%A8%D8%B2','Entertainment','Urdunews'],
                  ['https://www.urdunews.com/sections/%DA%A9%DA%BE%DB%8C%D9%84','Sports','Urdunews']
                 ]
    if Urdunews == True:
        i = 1
        counter = 0
        print('Getting Urdu News...')
        permalinkArrayUrdunews = []
        for source in sources28:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='column'):
                if i<=6:
                    try:
                        permalink = 'https://www.urdunews.com' + div.article.find('div',class_='article-item-title').h5.a['href']
                        permalinkArrayUrdunews.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
                i = 1
        detail_source = permalinkArrayUrdunews
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for article in soup.find_all('article'):
                try:
                    detail_title = article.find('div',class_='entry-title').h1.text   
                except:
                    detail_title = ''
                try:
                    high_resolution_image = article.find('div',class_='entry-media').img['src']  
                except:
                    high_resolution_image = ''

                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_all = article.find('div',class_='field-items').div.find_all('h5')
                    detail_description = ''
                    for h5 in detail_description_all:
                        detail_description = detail_description + h5.text.replace('\xa0','')
                except:
                    detail_description = ''
                counter = counter + 1
                language='English'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                }  
                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:20])
                    print('permalink:     ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter)
except:
    print('exception in ' + source[2])
# Out:
#   File "C:\Users\idenb\AppData\Local\Temp/ipykernel_14292/2399686019.py", line 102
#     print('total news scraped page : ' + str(counter)
#          ^
# SyntaxError: '(' was never closed

# %%
try:
    sources29 = [
                  ['https://www.samaa.tv/urdu/pakistan/','Pakistan','SamaUrdu'],
                  ['https://www.samaa.tv/urdu/international/','International','SamaUrdu'],
                  ['https://www.samaa.tv/urdu/entertainment/','Entertainment','SamaUrdu'],
                  ['https://www.samaa.tv/urdu/sports/','Sports','SamaUrdu'],
                  ['https://www.samaa.tv/urdu/tag/coronavirus/','Health','SamaUrdu']
                 ]
    if Sama == True:
        i = 1
        counter = 0
        permalinkArraySama = []
        for source in sources28:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='column'):
                if i<=6:
                    try:
                        permalink = 'https://www.urdunews.com' + div.article.find('div',class_='article-item-title').h5.a['href']
                        permalinkArraySama.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArraySama
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for article in soup.find_all('article'):
                try:
                    detail_title = article.find('div',class_='entry-title').h1.text
                except:
                    detail_title = ''
                try:
                    high_resolution_image = article.find('div',class_='entry-media').img['src']
                except:
                    high_resolution_image = ''

                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_all = article.find('div',class_='field-items').div.find_all('h5')
                    detail_description = ''
                    for h5 in detail_description_all:
                        detail_description = detail_description + h5.text.replace('\xa0','')
                except:
                    detail_description = ''
                counter = counter + 1
                language='English'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                }  
                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:20])
                    print('permalink:     ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])

# %%
try:
    sources30 = [
                  ['https://jang.com.pk/category/latest-news/national','National-local','Jangnews'],
                  ['https://jang.com.pk/category/latest-news/world','International','Jangnews'],
                  ['https://jang.com.pk/category/latest-news/entertainment','Entertainment','Jangnews'],
                  ['https://jang.com.pk/category/latest-news/sports','Sports','Jangnews'],
                  ['https://jang.com.pk/category/latest-news/health-science','Health','Jangnews']
                 ]
    if Jang == True:
        print('Getting Jang(showbiz) News...')
        i = 1
        counter = 0
        permalinkArrayJang = []
        for source in sources30:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for li in soup.find_all('li'):
                if i <= 6:
                    try:
                        permalink = li.find('div',class_='main-heading').a['href']
                        print(permalink)
                        permalinkArrayJang.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArrayJang
        print(detail_source)
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='detail-right'):
                try:
                    detail_title = div.div.h1.text
                except:
                    detail_title = ''
                try:
                    high_resolution_image = div.find('div',class_='detail-content').find('div',class_='description-area').find('div',class_='detail_view_content').div.figure.img['src']
                except:
                    high_resolution_image = ''

                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_all = div.find('div',class_='detail-content').find('div',class_='description-area').find('div',class_='detail_view_content').find_all('p')
                    detail_description = ''
                    for p in detail_description_all:
                        detail_description = detail_description + p.text.replace('\xa0','')
                except:
                    detail_description = ''
                counter = counter + 1
                language='Urdu'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                }  
                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:20])
                    print('permalink:     ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if False:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])

# %%
try:
    sources33 = [
                 ['https://tribune.com.pk/life-style/art-books','Fashion','Express Tribune'],
                 ['https://tribune.com.pk/life-style/fashion','Fashion','Express Tribune'],
                 ['https://tribune.com.pk/life-style/film','Entertainment','Express Tribune'],
                 ['https://tribune.com.pk/life-style/bollywood','Entertainment','Express Tribune'],
                 ['https://tribune.com.pk/life-style/gossip','Entertainment','Express Tribune'],
                 ['https://tribune.com.pk/life-style/theatre','Entertainment','Express Tribune'],
                 ['https://tribune.com.pk/life-style/tv','Entertainment','Express Tribune'],

                ]
    if Tribune == True:
        print('Getting Tribune Express News...')
        i = 1
        counter = 0
        permalinkArrayTribune = []
        for source in sources33:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for li in soup.find('ul',class_='listing-page').find_all('li'):
                if i <= 6:        
                    try:
                        permalink = li.find('div',class_='row').find('div',class_='col-md-8').find('div',class_='horiz-news3-caption').a['href']
                        permalinkArrayTribune.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArrayTribune
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='maincontent-customwidth'):
                try:
                    detail_title = div.find('div',class_='story-box-section').h1.text
                except:
                    detail_title = ''
                try:
                    high_resolution_image = div.find('div',class_='story-box-section').find('div',class_='mainstorycontent-parent').div.div.find('span',class_='top-big-img').div.div.div.img['data-src']
                except:
                    high_resolution_image = ''

                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_all = div.find('div',class_='story-box-section').find('div',class_='mainstorycontent-parent').div.div.find('span',class_='story-text').find_all('p')
                    detail_description = ''
                    for p in detail_description_all:
                        detail_description = detail_description + p.text.replace('\xa0','')
                except:
                    detail_description = detail_page_source[0]
                counter = counter + 1
                language='English'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                }  
                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:20])
                    print('permalink:     ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])

# %%
try:
    sources36 = [
                ['https://theislamicinformation.com/news/page/','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/2','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/3','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/4','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/5','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/6','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/7','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/8','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/9','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/10','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/11','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/12','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/13','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/14','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/15','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/16','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/17','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/18','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/19','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/20','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/21','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/22','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/23','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/24','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/25','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/26','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/27','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/28','Islam','The Islamic Information'],
                ['https://theislamicinformation.com/news/page/29','Islam','The Islamic Information'],
    ]
    if Islamicinfoenglish == True:
        i = 1
        counter = 0
        print('Getting Islamic info english...')
        permalinkArrayIslamicInformation = []
        for source in sources36:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for article in soup.find_all('article', class_='jeg_post'):
                if i <= 6:
                    try:
                        permalink = article.find('div',class_='jeg_thumb').a['href']
                        permalinkArrayIslamicInformation.append([permalink,source[1],source[2]])
                        counter = counter + 1
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArrayIslamicInformation
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='jeg_content'):
                try:
                    detail_title = div.div.find('div',class_='entry-header').h1.text
                except:
                    detail_title = ''

                try:
                    high_resolution_image = div.div.find('div',class_='jeg_main_content').find('div',class_='featured_image').a.div.img['data-src']
                except:
                    high_resolution_image = 'Pakteki'
                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_all = div.div.find('div',class_='jeg_main_content').div.find('div',class_='entry-content').find('div',class_='content-inner').find_all('p')
                    detail_description = ''
                    for p in detail_description_all:
                        detail_description = detail_description + p.text
                except:
                    detail_description = ''
                counter = counter + 1    
                language='English'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                            }
                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:20])
                    print('permalink:     ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])

# %%
try:
    sources37 = [
                ['https://islamqa.info/ur/latest','Islam','Islamicqa'],
                ['https://islamqa.info/ur/latest?page=2','Islam','Islamicqa'],
                ['https://islamqa.info/ur/latest?page=3','Islam','Islamicqa'],
                ['https://islamqa.info/ur/latest?page=4','Islam','Islamicqa'],
                ['https://islamqa.info/ur/latest?page=5','Islam','Islamicqa'],
                ['https://islamqa.info/ur/latest?page=6','Islam','Islamicqa'],
                ['https://islamqa.info/ur/latest?page=7','Islam','Islamicqa'],
                ['https://islamqa.info/ur/latest?page=8','Islam','Islamicqa'],
                ['https://islamqa.info/ur/latest?page=9','Islam','Islamicqa'],
                ['https://islamqa.info/ur/latest?page=10','Islam','Islamicqa'],
                ['https://islamqa.info/ur/latest?page=11','Islam','Islamicqa'],
                ['https://islamqa.info/ur/latest?page=12','Islam','Islamicqa'],
                ['https://islamqa.info/ur/latest?page=13','Islam','Islamicqa'],
                ['https://islamqa.info/ur/latest?page=14','Islam','Islamicqa'],
                ]
    if Islamicinfourdu == True:
        counter = 0
        print('Getting islamQA News...')
        i = 1
        permalinkArrayIslamicInformation = []
        for source in sources37:
            sourceHtml = requests.get(source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for a in soup.find_all('a', class_='card post-card'):
                if i<=6:
                    try:
                        permalink = a['href']
                        permalinkArrayIslamicInformation.append([permalink,source[1],source[2]])
                        counter = counter + 1 
                    except:
                        permalink = ''
                    i = i + 1
            i = 1
        detail_source = permalinkArrayIslamicInformation
        if developmentMode:
            print('total news found on listting page : ' + str(counter))
            df = pd.DataFrame(detail_source)
            df
        counter = 0
        for detail_page_source in detail_source:
            sourceHtml = requests.get(detail_page_source[0]).text
            soup = BeautifulSoup(sourceHtml, 'lxml')
            for div in soup.find_all('div',class_='single_fatwa'):
                try:
                    detail_title = div.find('div',class_='single-layout__title').h1.text.replace('\n','')
                except:
                    detail_title = ''
                try:
                    high_resolution_image = 'Pakteki'
                except:
                    high_resolution_image = ''
                try:
                    date_time = time.ctime()
                except:
                    date_time = ''
                try:
                    detail_description_answer_all = div.find('section',class_='single_fatwa__question').find_next_sibling().find('section',class_='single_fatwa__answer').find('section',class_='single_fatwa__answer__body').div.find_all('p')
                    detail_description_answer = ''
                    for p in detail_description_answer_all:
                        detail_description_answer = detail_description_answer + p.text
                    detail_description = div.find('section',class_='single_fatwa__question').h2.text + ' ' + div.find('section',class_='single_fatwa__question').div.p.text + ' ' + div.find('section',class_='single_fatwa__question').find_next_sibling().find('section',class_='single_fatwa__answer').h2.text + ' ' + detail_description_answer 
                except:
                    detail_description = ''
                counter = counter + 1    
                language='Urdu'
                values = {
                            'title': detail_title,
                            'description': detail_description,
                            'date': date_time,
                            'channel': source[2],
                            'image': high_resolution_image,
                            'permalink': detail_page_source[0],
                            'category': detail_page_source[1],
                            'fetching_date': date.today(),
                            'no_of_comments': 0,
                            'rating': 0,
                            'language':language,
                            'created_at': date.today(),
                            'updated_at': date.today(),
                            'comments': [],
                            'resgistered_views':[],
                            'no_of_registered_views':0,
                            'no_of_nonregistered_views':0,
                            }
                if developmentMode:
                    data.append([detail_title, source[1], source[2], permalink, high_resolution_image, date_time, detail_description, date.today(), language])
                    print('')
                    print('No:          ' + str(counter))
                    print('title:       ' + detail_title.strip())
                    print('description: ' + detail_description[0:20])
                    print('permalink:     ' + detail_page_source[0])
                    print('channel:     ' + source[2])
                    print('image:       ' + high_resolution_image)
                    print('category:    ' + detail_page_source[1])
                    print('-----------------------------------------------')
                    if callAPI:
                        response = requests.post(API, data=values)
                        if response.status_code == 429:
                            print('############ waiting response ..')
                            time.sleep(int(response.headers["Retry-After"]))
                        else:
                            print('inserted in DB')
                            print('-----------------------------------------------')
                else:
                    #data.append([detail_title.strip(), source[1], source[2], permalink, high_resolution_image, date_time, detail_description.strip(), date.today(), language])
                    response = requests.post(API, data=values)
                    if response.status_code == 429:
                        time.sleep(int(response.headers["Retry-After"]))
        if developmentMode:
            print('total news scraped page : ' + str(counter))
except:
    print('exception in ' + source[2])
